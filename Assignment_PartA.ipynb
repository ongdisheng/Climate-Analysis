# %% [markdown]
# # FIT3182 Assignment 3 Part A
#
# - Name: Ong Di Sheng
# - Student ID: 31109667
# - Email: dong0009@student.monash.edu

# %% [markdown]
# ## Task 1: MongoDB Data Model

# %% [markdown]
# ### ***1. Based on the two data sets provided i.e. hotspot_historic.csv and climate_historic.csv, design a suitable data model to support the efficient querying of the two data sets in MongoDB. Justify your data model design.*** ###

# %% [markdown]
# ### Answer ###

# %% [markdown]
# Before answering this question, let's first examine the data from both csv files to gain a better understanding of its structure, content and relationships by using pandas library.

# %%
# import libraries 
import pandas as pd
import pymongo

# show first 5 records from historic climate dataset
climate = pd.read_csv('climate_historic.csv')
climate.head()
# Out:
#    station        date  air_temperature_celcius  relative_humidity  \
# 0   948700  31/12/2021                       19               56.8
# 1   948700    2/1/2022                       15               50.7
# 2   948700    3/1/2022                       16               53.6
# 3   948700    4/1/2022                       24               61.6
# 4   948700    5/1/2022                       24               62.3
#
#    windspeed_knots  max_wind_speed precipitation   GHI_w/m2
# 0              7.9            11.1          0.00I       154
# 1              9.2            13.0          0.02G       128
# 2              8.1            15.0          0.00G       133
# 3              7.7            14.0          0.00I       186
# 4              7.0            13.0          0.00I       185

# %%
# show first 5 records from historic hotspot dataset
hotspot = pd.read_csv('hotspot_historic.csv')
hotspot.head()
# Out:
#    latitude  longitude             datetime  confidence        date  \
# 0   -37.966    145.051  2022-12-27T04:16:51          78  27/12/2022
# 1   -35.541    143.311  2022-12-27T00:02:15          82  27/12/2022
# 2   -35.554    143.307  2022-12-27T00:02:15          67  27/12/2022
# 3   -35.543    143.316  2022-12-27T00:02:14          86  27/12/2022
# 4   -37.708    145.100  2022-12-25T04:29:08          80  25/12/2022
#
#    surface_temperature_celcius
# 0                           68
# 1                           63
# 2                           53
# 3                           67
# 4                           54

# %% [markdown]
# Based on the assignment specifications, there exists a relationship between climate and hotspot data. A climate data entry can have zero or multiple corresponding hotspot data entries, depending on the occurrence of fires on a specific day. To establish this connection, we can utilize the date field as a shared identifier. In the provided example, I have specifically selected rows from both datasets that have the date 29/3/2022 as a reference point for building the data model.

# %%
climate[climate['date'] == '29/3/2022']
# Out:
#     station       date  air_temperature_celcius  relative_humidity  \
# 87   948701  29/3/2022                       17               49.9
#
#     windspeed_knots  max_wind_speed precipitation   GHI_w/m2
# 87             12.2            21.0          0.24G       146

# %%
hotspot[hotspot['date'] == '29/3/2022']
# Out:
#       latitude  longitude             datetime  confidence       date  \
# 2511  -34.2648   141.6325  2022-03-29T00:48:40          69  29/3/2022
#
#       surface_temperature_celcius
# 2511                           51

# %% [markdown]
# Based on the provided sample data, we can create an example representation of how the collections might be structured in MongoDB.

# %% [markdown]
# #### Climate Collection: ####
# ```
# {
#    'GHI_w/m2': 146,
#    '_id': ObjectId('64794430094ec77d3a57cc2e'),
#    'air_temperature_celcius': 17,
#    'date': datetime.datetime(2022, 3, 29, 0, 0),
#    'max_wind_speed': 21.0,
#    'precipitation': 0.24,
#    'precipitation_flag': 'G',
#    'relative_humidity': 49.9,
#    'station': 948701,
#    'windspeed_knots': 12.2
# }
# ```

# %% [markdown]
# #### Hotspot Collection: ####
# ```
# {
#    'confidence': 69,
#    'date': datetime.datetime(2022, 3, 29, 0, 0),
#    'datetime': datetime.datetime(2022, 3, 29, 0, 48, 40),
#    'latitude': -34.2648,
#    'longitude': 141.6325,
#    'surface_temperature_celcius': 51
# }
# ```

# %% [markdown]
# After careful consideration, I have decided to construct an embedded data model for this assignment in order to support the efficient querying of the two datasets in MongoDB as shown below.

# %% [markdown]
# #### `Example of Embedded Data Model:` ####
# ```
# {
#    'GHI_w/m2': 146,
#    '_id': ObjectId('64794430094ec77d3a57cc2e'),
#    'air_temperature_celcius': 17,
#    'date': datetime.datetime(2022, 3, 29, 0, 0),
#    'max_wind_speed': 21.0,
#    'precipitation': 0.24,
#    'precipitation_flag': 'G',
#    'relative_humidity': 49.9,
#    'station': 948701,
#    'windspeed_knots': 12.2,
#    'hotspots': [
#        {
#            'confidence': 69,
#            'date': datetime.datetime(2022, 3, 29, 0, 0),
#            'datetime': datetime.datetime(2022, 3, 29, 0, 48, 40),
#            'latitude': -34.2648,
#            'longitude': 141.6325,
#            'surface_temperature_celcius': 51
#        }
#    ]
# }
# ```

# %% [markdown]
# #### `Justification:` ####
#
# Based on initial observations of the historic climate and hotspot data, it is apparent that there is consistently only one climate entry per day. However, there can be multiple hotspot entries recorded for a single day. This suggests a one-to-many relationship from climate data to hotspot data. Considering this relationship, an embedded data model is more suitable. In this proposed embedded data model, each climate data entry will include an array called "hotspots". For every hotspot data entry with the same date as the climate data, it will be appended to this array.
#
# One of the advantages of using an embedded data model is the convenience it offers by having all the required data in a single collection. In the case of Task 2 below, where querying data from both csv files is necessary, opting for a referencing data model would involve performing several left outer join operations using aggregations. As the dataset grows larger, this approach can become expensive and time-consuming due to the total join cost. On the other hand, with an embedded data model, there is no need to perform any join operations since all the relevant information is stored within one collection. This approach significantly reduces computational complexity and simplifies the querying workflow by eliminating the need for separate lookups or complex join operations.
#
# While an embedded data model offers numerous advantages, there are certain drawbacks to consider. One notable downside is that the size of the document can increase significantly if there are numerous hotspot entries associated with a single climate entry. However, in our specific case, this is not a major concern since MongoDB's document size limit of 16MB is more than sufficient to accommodate a substantial amount of hotspot data as it is highly unlikely to encounter a scenario where thousands of fires break out across Victoria in a single day.
#
# Based on the aforementioned considerations, I am confident that the embedded data model is the most suitable choice for storing climate and hotspot data in our specific application. Therefore, I have made the decision to utilize this model for our project.

# %% [markdown]
# ## Task 2: Querying MongoDB using PyMongo

# %% [markdown]
# ### ***1. Write a python program that will read the data from hotspot_historic.csv and climate_historic.csv and load them to the new database (e.g. fit3182_assignment_db). The collection(s) in fit3182_assignment_db will be based on the document model you have designed in Task A1.*** ###

# %%
# import libraries 
import pandas as pd
from pymongo import MongoClient
from pprint import pprint
from datetime import datetime

# read data from csv files
climate = pd.read_csv('climate_historic.csv')
hotspot = pd.read_csv('hotspot_historic.csv')

# identify data types
# print(climate.dtypes)
# print(hotspot.dtypes)

# convert data types (datetime)
climate['date'] = pd.to_datetime(climate['date'], format='%d/%m/%Y')
hotspot['date'] = pd.to_datetime(hotspot['date'], format='%d/%m/%Y')
hotspot['datetime'] = pd.to_datetime(hotspot['datetime'], format='%Y-%m-%dT%H:%M:%S')

# format date columns
climate['date'] = climate['date'].dt.strftime('%d-%m-%Y')
hotspot['date'] = hotspot['date'].dt.strftime('%d-%m-%Y')
hotspot['datetime'] = hotspot['datetime'].dt.strftime('%Y-%m-%dT%H:%M:%S')

# construct embedded model 
# iterate over every record from climate data (as a dictionary)
climate_dict = climate.to_dict('records')
for climate_doc in climate_dict:
        
    # remove whitespace in `precipitation `
    climate_doc['precipitation'] = climate_doc['precipitation ']
    del climate_doc['precipitation ']
    
    # separate `precipitation` into value and flag
    precipitation = climate_doc['precipitation']
    climate_doc['precipitation'] = float(precipitation[:-1])
    climate_doc['precipitation_flag'] = precipitation[-1]
    
    # retrieve hotspot record(s) with matching date as current climate
    matching_hotspot = hotspot[hotspot['date'] == climate_doc['date']]
    
    # update climate date format before inserting into db
    climate_doc['date'] = datetime.strptime(climate_doc['date'], '%d-%m-%Y')
    
    # to be embedded with hotspot documents
    climate_doc['hotspots'] = []
    
    # iterate over every record from matching hotspot data (as a dictionary)
    for hotspot_doc in matching_hotspot.to_dict('records'):
        
        # update hotspot date format before inserting into db
        hotspot_doc['date'] = datetime.strptime(hotspot_doc['date'], '%d-%m-%Y')
        hotspot_doc['datetime'] = datetime.strptime(hotspot_doc['datetime'], '%Y-%m-%dT%H:%M:%S')
        
        # embed with hotspot document
        climate_doc['hotspots'].append(hotspot_doc)

# %%
# create connection with mongodb
# replace with your own IP address and port number
client = MongoClient('192.168.1.110', 27017)

# access database 
db = client.fit3182_assignment_db

# access collection
collection = db.embedded_climate_hotspot

# drop collection if it already exists in db
collection.drop()

# load processed data into db collection
result = collection.insert_many(climate_dict)

# show all newly inserted documents
for document in collection.find():
    pprint(document)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6481357e25c02be8d1a097ad'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 12, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('6481357e25c02be8d1a097ae'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2022, 1, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('6481357e25c02be8d1a097af'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('6481357e25c02be8d1a097b0'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2022, 1, 4, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('6481357e25c02be8d1a097b1'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2022, 1, 5, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('6481357e25c02be8d1a097b2'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2022, 1, 6, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('6481357e25c02be8d1a097b3'),
#  'air_temperature_celcius': 32,
#  'date': datetime.datetime(2022, 1, 7, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('6481357e25c02be8d1a097b4'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 1, 8, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6481357e25c02be8d1a097b5'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 1, 9, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6481357e25c02be8d1a097b6'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 1, 10, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a097b7'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 1, 11, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.3,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 179,
#  '_id': ObjectId('6481357e25c02be8d1a097b8'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2022, 1, 12, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.08,
#  'precipitation_flag': 'G',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 157,
#  '_id': ObjectId('6481357e25c02be8d1a097b9'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 1, 13, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6481357e25c02be8d1a097ba'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 1, 14, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 50.4,
#  'station': 948700,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('6481357e25c02be8d1a097bb'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 15, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('6481357e25c02be8d1a097bc'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2022, 1, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.4,
#  'station': 948700,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 200,
#  '_id': ObjectId('6481357e25c02be8d1a097bd'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2022, 1, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('6481357e25c02be8d1a097be'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 18, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 46.7,
#  'station': 948700,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('6481357e25c02be8d1a097bf'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 1, 19, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.98,
#  'precipitation_flag': 'G',
#  'relative_humidity': 57.2,
#  'station': 948700,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('6481357e25c02be8d1a097c0'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.03,
#  'precipitation_flag': 'G',
#  'relative_humidity': 50.9,
#  'station': 948700,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6481357e25c02be8d1a097c1'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 1, 21, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 52.5,
#  'station': 948700,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 182,
#  '_id': ObjectId('6481357e25c02be8d1a097c2'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2022, 1, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 59.0,
#  'station': 948700,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('6481357e25c02be8d1a097c3'),
#  'air_temperature_celcius': 25,
#  'date': datetime.datetime(2022, 1, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 22.0,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'relative_humidity': 58.3,
#  'station': 948700,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6481357e25c02be8d1a097c4'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 24, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.2,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6481357e25c02be8d1a097c5'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 1, 25, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a097c6'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 1, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.5,
#  'station': 948700,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('6481357e25c02be8d1a097c7'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 1, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'A',
#  'relative_humidity': 56.1,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6481357e25c02be8d1a097c8'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 1, 28, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('6481357e25c02be8d1a097c9'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2022, 1, 29, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 58.0,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('6481357e25c02be8d1a097ca'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 1, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 55.8,
#  'station': 948700,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6481357e25c02be8d1a097cb'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.4,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 138,
#  '_id': ObjectId('6481357e25c02be8d1a097cc'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 2, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 48.9,
#  'station': 948700,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a097cd'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 2, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.0,
#  'station': 948700,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('6481357e25c02be8d1a097ce'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 2, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 54.4,
#  'station': 948700,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 216,
#  '_id': ObjectId('6481357e25c02be8d1a097cf'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2022, 2, 4, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.7,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6481357e25c02be8d1a097d0'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 2, 5, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 1.26,
#  'precipitation_flag': 'G',
#  'relative_humidity': 64.5,
#  'station': 948700,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6481357e25c02be8d1a097d1'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 2, 6, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.1,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6481357e25c02be8d1a097d2'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 2, 7, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 22.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 57.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 239,
#  '_id': ObjectId('6481357e25c02be8d1a097d3'),
#  'air_temperature_celcius': 31,
#  'date': datetime.datetime(2022, 2, 8, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 23.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 61.9,
#  'station': 948700,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('6481357e25c02be8d1a097d4'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2022, 2, 9, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 62.7,
#  'station': 948700,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 164,
#  '_id': ObjectId('6481357e25c02be8d1a097d5'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 2, 10, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 60.4,
#  'station': 948700,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6481357e25c02be8d1a097d6'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 2, 11, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.8,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6481357e25c02be8d1a097d7'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 2, 12, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.3,
#  'station': 948700,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('6481357e25c02be8d1a097d8'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 2, 13, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.16,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('6481357e25c02be8d1a097d9'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2022, 2, 14, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('6481357e25c02be8d1a097da'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2022, 2, 15, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a097db'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 2, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('6481357e25c02be8d1a097dc'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 2, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 49.4,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 134,
#  '_id': ObjectId('6481357e25c02be8d1a097dd'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2022, 2, 18, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.6,
#  'station': 948700,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 113,
#  '_id': ObjectId('6481357e25c02be8d1a097de'),
#  'air_temperature_celcius': 13,
#  'date': datetime.datetime(2022, 2, 19, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.71,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('6481357e25c02be8d1a097df'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2022, 2, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.1,
#  'station': 948701,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('6481357e25c02be8d1a097e0'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 2, 21, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 51.0,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('6481357e25c02be8d1a097e1'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2022, 2, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 49.6,
#  'station': 948701,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('6481357e25c02be8d1a097e2'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 2, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 55.5,
#  'station': 948701,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6481357e25c02be8d1a097e3'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 2, 24, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.3,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6481357e25c02be8d1a097e4'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 2, 25, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 52.6,
#  'station': 948701,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 173,
#  '_id': ObjectId('6481357e25c02be8d1a097e5'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 2, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('6481357e25c02be8d1a097e6'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2022, 2, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 190,
#  '_id': ObjectId('6481357e25c02be8d1a097e7'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2022, 2, 28, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 54.1,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('6481357e25c02be8d1a097e8'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 3, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 57.3,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('6481357e25c02be8d1a097e9'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 3, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 62.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('6481357e25c02be8d1a097ea'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 3, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 59.5,
#  'station': 948701,
#  'windspeed_knots': 12.4}
# {'GHI_w/m2': 170,
#  '_id': ObjectId('6481357e25c02be8d1a097eb'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2022, 3, 4, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 62.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('6481357e25c02be8d1a097ec'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 3, 5, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 58.8,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('6481357e25c02be8d1a097ed'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 3, 6, 0, 0),
#  'hotspots': [{'confidence': 87,
#                'date': datetime.datetime(2022, 3, 6, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 6, 5, 6, 30),
#                'latitude': -34.3795,
#                'longitude': 141.6331,
#                'surface_temperature_celcius': 62},
#               {'confidence': 85,
#                'date': datetime.datetime(2022, 3, 6, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 6, 5, 6, 20),
#                'latitude': -34.3735,
#                'longitude': 141.6604,
#                'surface_temperature_celcius': 59}],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.9,
#  'station': 948701,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6481357e25c02be8d1a097ee'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 3, 7, 0, 0),
#  'hotspots': [{'confidence': 88,
#                'date': datetime.datetime(2022, 3, 7, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 7, 4, 16, 10),
#                'latitude': -37.7752,
#                'longitude': 141.9086,
#                'surface_temperature_celcius': 64}],
#  'max_wind_speed': 20.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 51.5,
#  'station': 948701,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 177,
#  '_id': ObjectId('6481357e25c02be8d1a097ef'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 3, 8, 0, 0),
#  'hotspots': [{'confidence': 68,
#                'date': datetime.datetime(2022, 3, 8, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 8, 4, 51),
#                'latitude': -37.7885,
#                'longitude': 141.9352,
#                'surface_temperature_celcius': 55},
#               {'confidence': 75,
#                'date': datetime.datetime(2022, 3, 8, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 8, 0, 30, 30),
#                'latitude': -38.1031,
#                'longitude': 142.4797,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 192,
#  '_id': ObjectId('6481357e25c02be8d1a097f0'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2022, 3, 9, 0, 0),
#  'hotspots': [{'confidence': 86,
#                'date': datetime.datetime(2022, 3, 9, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 9, 13, 23, 40),
#                'latitude': -37.996,
#                'longitude': 146.3535,
#                'surface_temperature_celcius': 41},
#               {'confidence': 54,
#                'date': datetime.datetime(2022, 3, 9, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 9, 3, 57),
#                'latitude': -37.7171,
#                'longitude': 147.5866,
#                'surface_temperature_celcius': 44},
#               {'confidence': 78,
#                'date': datetime.datetime(2022, 3, 9, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 9, 3, 56, 50),
#                'latitude': -37.7074,
#                'longitude': 147.5849,
#                'surface_temperature_celcius': 55}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('6481357e25c02be8d1a097f1'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 3, 10, 0, 0),
#  'hotspots': [{'confidence': 100,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 48, 40),
#                'latitude': -37.223,
#                'longitude': 147.9431,
#                'surface_temperature_celcius': 105},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 46, 20),
#                'latitude': -37.2252,
#                'longitude': 147.9363,
#                'surface_temperature_celcius': 109},
#               {'confidence': 94,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 45, 30),
#                'latitude': -37.2284,
#                'longitude': 147.9187,
#                'surface_temperature_celcius': 73},
#               {'confidence': 97,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 45, 30),
#                'latitude': -37.6572,
#                'longitude': 142.0703,
#                'surface_temperature_celcius': 80},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 43, 50),
#                'latitude': -37.6592,
#                'longitude': 142.058,
#                'surface_temperature_celcius': 55},
#               {'confidence': 55,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 43),
#                'latitude': -36.2544,
#                'longitude': 148.0353,
#                'surface_temperature_celcius': 42},
#               {'confidence': 54,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 42, 30),
#                'latitude': -37.2197,
#                'longitude': 147.9621,
#                'surface_temperature_celcius': 43},
#               {'confidence': 74,
#                'date': datetime.datetime(2022, 3, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 10, 4, 39),
#                'latitude': -37.2128,
#                'longitude': 147.9308,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6481357e25c02be8d1a097f2'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 3, 11, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 59.7,
#  'station': 948701,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 168,
#  '_id': ObjectId('6481357e25c02be8d1a097f3'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 3, 12, 0, 0),
#  'hotspots': [{'confidence': 94,
#                'date': datetime.datetime(2022, 3, 12, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 12, 4, 33, 50),
#                'latitude': -37.4157,
#                'longitude': 147.0084,
#                'surface_temperature_celcius': 105},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 3, 12, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 12, 4, 29, 50),
#                'latitude': -37.0193,
#                'longitude': 148.1459,
#                'surface_temperature_celcius': 71},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 3, 12, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 12, 4, 28, 20),
#                'latitude': -37.4229,
#                'longitude': 147.027,
#                'surface_temperature_celcius': 99},
#               {'confidence': 80,
#                'date': datetime.datetime(2022, 3, 12, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 12, 4, 28),
#                'latitude': -37.0055,
#                'longitude': 148.1582,
#                'surface_temperature_celcius': 68},
#               {'confidence': 85,
#                'date': datetime.datetime(2022, 3, 12, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 12, 4, 27, 20),
#                'latitude': -37.4128,
#                'longitude': 147.0242,
#                'surface_temperature_celcius': 98}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 58.1,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6481357e25c02be8d1a097f4'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 3, 13, 0, 0),
#  'hotspots': [{'confidence': 56,
#                'date': datetime.datetime(2022, 3, 13, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 13, 23, 58, 50),
#                'latitude': -37.0286,
#                'longitude': 148.155,
#                'surface_temperature_celcius': 42},
#               {'confidence': 52,
#                'date': datetime.datetime(2022, 3, 13, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 13, 12, 57),
#                'latitude': -37.0316,
#                'longitude': 148.1519,
#                'surface_temperature_celcius': 35}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('6481357e25c02be8d1a097f5'),
#  'air_temperature_celcius': 25,
#  'date': datetime.datetime(2022, 3, 14, 0, 0),
#  'hotspots': [{'confidence': 90,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 24, 40),
#                'latitude': -34.357,
#                'longitude': 141.5361,
#                'surface_temperature_celcius': 67},
#               {'confidence': 93,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 22, 20),
#                'latitude': -34.3539,
#                'longitude': 141.5547,
#                'surface_temperature_celcius': 72},
#               {'confidence': 90,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 20, 50),
#                'latitude': -36.9939,
#                'longitude': 148.2244,
#                'surface_temperature_celcius': 68},
#               {'confidence': 73,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 19, 30),
#                'latitude': -36.998,
#                'longitude': 148.1994,
#                'surface_temperature_celcius': 48},
#               {'confidence': 95,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 16, 30),
#                'latitude': -36.9959,
#                'longitude': 148.2118,
#                'surface_temperature_celcius': 75},
#               {'confidence': 89,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 16, 20),
#                'latitude': -34.3654,
#                'longitude': 141.543,
#                'surface_temperature_celcius': 65},
#               {'confidence': 73,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 14, 40),
#                'latitude': -37.0228,
#                'longitude': 148.1996,
#                'surface_temperature_celcius': 52},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 14, 40),
#                'latitude': -34.3539,
#                'longitude': 141.5629,
#                'surface_temperature_celcius': 55},
#               {'confidence': 96,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 14, 30),
#                'latitude': -34.3554,
#                'longitude': 141.5413,
#                'surface_temperature_celcius': 79},
#               {'confidence': 94,
#                'date': datetime.datetime(2022, 3, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 14, 4, 14, 30),
#                'latitude': -34.3555,
#                'longitude': 141.5495,
#                'surface_temperature_celcius': 75}],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 58.3,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('6481357e25c02be8d1a097f6'),
#  'air_temperature_celcius': 28,
#  'date': datetime.datetime(2022, 3, 15, 0, 0),
#  'hotspots': [{'confidence': 76,
#                'date': datetime.datetime(2022, 3, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 15, 5, 2),
#                'latitude': -37.4108,
#                'longitude': 147.0196,
#                'surface_temperature_celcius': 50},
#               {'confidence': 74,
#                'date': datetime.datetime(2022, 3, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 15, 4, 59, 10),
#                'latitude': -37.4058,
#                'longitude': 147.0117,
#                'surface_temperature_celcius': 48},
#               {'confidence': 52,
#                'date': datetime.datetime(2022, 3, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#                'latitude': -37.4075,
#                'longitude': 147.0233,
#                'surface_temperature_celcius': 43},
#               {'confidence': 66,
#                'date': datetime.datetime(2022, 3, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#                'latitude': -37.0228,
#                'longitude': 148.1281,
#                'surface_temperature_celcius': 43},
#               {'confidence': 51,
#                'date': datetime.datetime(2022, 3, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 15, 0, 42, 40),
#                'latitude': -37.002,
#                'longitude': 148.2055,
#                'surface_temperature_celcius': 44},
#               {'confidence': 75,
#                'date': datetime.datetime(2022, 3, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 15, 0, 38, 10),
#                'latitude': -37.0249,
#                'longitude': 148.1561,
#                'surface_temperature_celcius': 49},
#               {'confidence': 70,
#                'date': datetime.datetime(2022, 3, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 15, 0, 37, 20),
#                'latitude': -37.4098,
#                'longitude': 147.0489,
#                'surface_temperature_celcius': 45}],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a097f7'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 3, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.3,
#  'station': 948701,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('6481357e25c02be8d1a097f8'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 3, 17, 0, 0),
#  'hotspots': [{'confidence': 76,
#                'date': datetime.datetime(2022, 3, 17, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 17, 4, 48, 20),
#                'latitude': -34.3383,
#                'longitude': 141.543,
#                'surface_temperature_celcius': 56},
#               {'confidence': 94,
#                'date': datetime.datetime(2022, 3, 17, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 17, 4, 48, 20),
#                'latitude': -36.7152,
#                'longitude': 141.3853,
#                'surface_temperature_celcius': 74},
#               {'confidence': 78,
#                'date': datetime.datetime(2022, 3, 17, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 17, 4, 46, 40),
#                'latitude': -34.328,
#                'longitude': 141.5402,
#                'surface_temperature_celcius': 58},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 3, 17, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 17, 4, 45, 10),
#                'latitude': -36.6867,
#                'longitude': 141.137,
#                'surface_temperature_celcius': 59},
#               {'confidence': 76,
#                'date': datetime.datetime(2022, 3, 17, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 17, 4, 45),
#                'latitude': -36.6889,
#                'longitude': 141.1239,
#                'surface_temperature_celcius': 50},
#               {'confidence': 86,
#                'date': datetime.datetime(2022, 3, 17, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 17, 4, 45),
#                'latitude': -36.7128,
#                'longitude': 141.3986,
#                'surface_temperature_celcius': 60}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 51.1,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('6481357e25c02be8d1a097f9'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 3, 18, 0, 0),
#  'hotspots': [{'confidence': 64,
#                'date': datetime.datetime(2022, 3, 18, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 18, 13, 16, 50),
#                'latitude': -37.4313,
#                'longitude': 147.0343,
#                'surface_temperature_celcius': 37},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 3, 18, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 18, 3, 50, 50),
#                'latitude': -37.017,
#                'longitude': 148.1297,
#                'surface_temperature_celcius': 121},
#               {'confidence': 97,
#                'date': datetime.datetime(2022, 3, 18, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 18, 3, 50, 40),
#                'latitude': -37.0155,
#                'longitude': 148.1432,
#                'surface_temperature_celcius': 80}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('6481357e25c02be8d1a097fa'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2022, 3, 19, 0, 0),
#  'hotspots': [{'confidence': 85,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 39, 50),
#                'latitude': -37.6605,
#                'longitude': 142.1116,
#                'surface_temperature_celcius': 60},
#               {'confidence': 58,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#                'latitude': -37.9164,
#                'longitude': 143.4866,
#                'surface_temperature_celcius': 54},
#               {'confidence': 96,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#                'latitude': -37.6622,
#                'longitude': 142.1001,
#                'surface_temperature_celcius': 79},
#               {'confidence': 63,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#                'latitude': -37.9257,
#                'longitude': 143.4891,
#                'surface_temperature_celcius': 54},
#               {'confidence': 64,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 36),
#                'latitude': -37.3982,
#                'longitude': 147.0001,
#                'surface_temperature_celcius': 58},
#               {'confidence': 90,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 36),
#                'latitude': -37.4523,
#                'longitude': 147.0175,
#                'surface_temperature_celcius': 66},
#               {'confidence': 59,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 35),
#                'latitude': -37.4023,
#                'longitude': 147.0394,
#                'surface_temperature_celcius': 56},
#               {'confidence': 60,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 33, 50),
#                'latitude': -37.4336,
#                'longitude': 147.0534,
#                'surface_temperature_celcius': 51},
#               {'confidence': 61,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 33, 30),
#                'latitude': -37.4003,
#                'longitude': 147.0448,
#                'surface_temperature_celcius': 55},
#               {'confidence': 53,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 33, 30),
#                'latitude': -37.9184,
#                'longitude': 143.4745,
#                'surface_temperature_celcius': 55},
#               {'confidence': 61,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 33, 10),
#                'latitude': -37.3911,
#                'longitude': 147.037,
#                'surface_temperature_celcius': 50},
#               {'confidence': 98,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 33),
#                'latitude': -37.4261,
#                'longitude': 147.0323,
#                'surface_temperature_celcius': 83},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#                'latitude': -37.3949,
#                'longitude': 147.0175,
#                'surface_temperature_celcius': 91},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#                'latitude': -37.671,
#                'longitude': 144.6536,
#                'surface_temperature_celcius': 58},
#               {'confidence': 66,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#                'latitude': -37.9277,
#                'longitude': 143.477,
#                'surface_temperature_celcius': 55},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#                'latitude': -37.4224,
#                'longitude': 147.0511,
#                'surface_temperature_celcius': 113},
#               {'confidence': 92,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#                'latitude': -37.6625,
#                'longitude': 144.287,
#                'surface_temperature_celcius': 70},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#                'latitude': -37.4375,
#                'longitude': 147.0336,
#                'surface_temperature_celcius': 106},
#               {'confidence': 73,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#                'latitude': -37.4414,
#                'longitude': 147.0139,
#                'surface_temperature_celcius': 60},
#               {'confidence': 77,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 0, 15, 50),
#                'latitude': -37.4295,
#                'longitude': 147.0428,
#                'surface_temperature_celcius': 59},
#               {'confidence': 60,
#                'date': datetime.datetime(2022, 3, 19, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 19, 0, 12, 50),
#                'latitude': -37.3942,
#                'longitude': 147.0455,
#                'surface_temperature_celcius': 44}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 174,
#  '_id': ObjectId('6481357e25c02be8d1a097fb'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2022, 3, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.08,
#  'precipitation_flag': 'G',
#  'relative_humidity': 63.8,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('6481357e25c02be8d1a097fc'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 3, 21, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.63,
#  'precipitation_flag': 'G',
#  'relative_humidity': 67.4,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6481357e25c02be8d1a097fd'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 3, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 57.5,
#  'station': 948701,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('6481357e25c02be8d1a097fe'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 3, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('6481357e25c02be8d1a097ff'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 3, 24, 0, 0),
#  'hotspots': [{'confidence': 65,
#                'date': datetime.datetime(2022, 3, 24, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 24, 4, 58),
#                'latitude': -37.1603,
#                'longitude': 142.8088,
#                'surface_temperature_celcius': 50},
#               {'confidence': 55,
#                'date': datetime.datetime(2022, 3, 24, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 24, 4, 56, 10),
#                'latitude': -37.1684,
#                'longitude': 142.8183,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('6481357e25c02be8d1a09800'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2022, 3, 25, 0, 0),
#  'hotspots': [{'confidence': 76,
#                'date': datetime.datetime(2022, 3, 25, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 25, 4, 3, 10),
#                'latitude': -37.8025,
#                'longitude': 145.8702,
#                'surface_temperature_celcius': 49},
#               {'confidence': 62,
#                'date': datetime.datetime(2022, 3, 25, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 25, 4, 3, 10),
#                'latitude': -37.8992,
#                'longitude': 143.4534,
#                'surface_temperature_celcius': 54},
#               {'confidence': 78,
#                'date': datetime.datetime(2022, 3, 25, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 25, 3, 59, 50),
#                'latitude': -37.8758,
#                'longitude': 145.8371,
#                'surface_temperature_celcius': 52},
#               {'confidence': 82,
#                'date': datetime.datetime(2022, 3, 25, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 25, 3, 59, 50),
#                'latitude': -37.8973,
#                'longitude': 143.4754,
#                'surface_temperature_celcius': 65},
#               {'confidence': 87,
#                'date': datetime.datetime(2022, 3, 25, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 25, 3, 58, 10),
#                'latitude': -37.7829,
#                'longitude': 143.5056,
#                'surface_temperature_celcius': 62},
#               {'confidence': 95,
#                'date': datetime.datetime(2022, 3, 25, 0, 0),
# ...
#  'station': 948702,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('6481357e25c02be8d1a09904'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 12, 10, 0, 0),
#  'hotspots': [{'confidence': 50,
#                'date': datetime.datetime(2022, 12, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 10, 0, 57, 59),
#                'latitude': -37.987,
#                'longitude': 144.005,
#                'surface_temperature_celcius': 38},
#               {'confidence': 67,
#                'date': datetime.datetime(2022, 12, 10, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 10, 0, 56, 57),
#                'latitude': -34.289,
#                'longitude': 141.712,
#                'surface_temperature_celcius': 54}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6481357e25c02be8d1a09905'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 12, 11, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('6481357e25c02be8d1a09906'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 12, 12, 0, 0),
#  'hotspots': [{'confidence': 53,
#                'date': datetime.datetime(2022, 12, 12, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 12, 0, 45, 38),
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celcius': 44}],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 240,
#  '_id': ObjectId('6481357e25c02be8d1a09907'),
#  'air_temperature_celcius': 28,
#  'date': datetime.datetime(2022, 12, 13, 0, 0),
#  'hotspots': [{'confidence': 83,
#                'date': datetime.datetime(2022, 12, 13, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 13, 4, 4, 19),
#                'latitude': -38.231,
#                'longitude': 147.172,
#                'surface_temperature_celcius': 60}],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 49.9,
#  'station': 948702,
#  'windspeed_knots': 11.0}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6481357e25c02be8d1a09908'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 12, 14, 0, 0),
#  'hotspots': [{'confidence': 92,
#                'date': datetime.datetime(2022, 12, 14, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 14, 4, 47, 25),
#                'latitude': -37.95,
#                'longitude': 142.366,
#                'surface_temperature_celcius': 70}],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('6481357e25c02be8d1a09909'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 12, 15, 0, 0),
#  'hotspots': [{'confidence': 92,
#                'date': datetime.datetime(2022, 12, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#                'latitude': -37.627,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 42},
#               {'confidence': 78,
#                'date': datetime.datetime(2022, 12, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#                'latitude': -37.658,
#                'longitude': 149.339,
#                'surface_temperature_celcius': 36},
#               {'confidence': 51,
#                'date': datetime.datetime(2022, 12, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#                'latitude': -37.623,
#                'longitude': 149.323,
#                'surface_temperature_celcius': 38},
#               {'confidence': 65,
#                'date': datetime.datetime(2022, 12, 15, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 15, 1, 16, 23),
#                'latitude': -38.038,
#                'longitude': 142.986,
#                'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a0990a'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspots': [{'confidence': 94,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#                'latitude': -37.636,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 43},
#               {'confidence': 69,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#                'latitude': -37.624,
#                'longitude': 149.332,
#                'surface_temperature_celcius': 33},
#               {'confidence': 62,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 35, 15),
#                'latitude': -37.82,
#                'longitude': 142.323,
#                'surface_temperature_celcius': 54},
#               {'confidence': 93,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 35, 13),
#                'latitude': -37.875,
#                'longitude': 142.51,
#                'surface_temperature_celcius': 73},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#                'latitude': -37.608,
#                'longitude': 149.328,
#                'surface_temperature_celcius': 55},
#               {'confidence': 95,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#                'latitude': -37.613,
#                'longitude': 149.305,
#                'surface_temperature_celcius': 75},
#               {'confidence': 59,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#                'latitude': -37.644,
#                'longitude': 149.346,
#                'surface_temperature_celcius': 55},
#               {'confidence': 90,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#                'latitude': -37.624,
#                'longitude': 149.314,
#                'surface_temperature_celcius': 66},
#               {'confidence': 75,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#                'latitude': -37.661,
#                'longitude': 149.327,
#                'surface_temperature_celcius': 56},
#               {'confidence': 79,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#                'latitude': -37.649,
#                'longitude': 149.322,
#                'surface_temperature_celcius': 60},
#               {'confidence': 93,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 0, 21, 12),
#                'latitude': -38.057,
#                'longitude': 144.211,
#                'surface_temperature_celcius': 73},
#               {'confidence': 60,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#                'latitude': -38.046,
#                'longitude': 144.201,
#                'surface_temperature_celcius': 48},
#               {'confidence': 82,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#                'latitude': -38.048,
#                'longitude': 144.213,
#                'surface_temperature_celcius': 55},
#               {'confidence': 82,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#                'latitude': -37.651,
#                'longitude': 149.345,
#                'surface_temperature_celcius': 64},
#               {'confidence': 53,
#                'date': datetime.datetime(2022, 12, 16, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#                'latitude': -37.63,
#                'longitude': 149.335,
#                'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('6481357e25c02be8d1a0990b'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 12, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 195,
#  '_id': ObjectId('6481357e25c02be8d1a0990c'),
#  'air_temperature_celcius': 25,
#  'date': datetime.datetime(2022, 12, 18, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 60.9,
#  'station': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('6481357e25c02be8d1a0990d'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 12, 19, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 22.9,
#  'precipitation': 0.67,
#  'precipitation_flag': 'G',
#  'relative_humidity': 57.4,
#  'station': 948702,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 144,
#  '_id': ObjectId('6481357e25c02be8d1a0990e'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 12, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 51.2,
#  'station': 948702,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6481357e25c02be8d1a0990f'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 12, 21, 0, 0),
#  'hotspots': [{'confidence': 72,
#                'date': datetime.datetime(2022, 12, 21, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 21, 4, 53, 29),
#                'latitude': -38.075,
#                'longitude': 143.76,
#                'surface_temperature_celcius': 46}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('6481357e25c02be8d1a09910'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 12, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.8,
#  'station': 948702,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6481357e25c02be8d1a09911'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 12, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.9,
#  'station': 948702,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('6481357e25c02be8d1a09912'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 12, 24, 0, 0),
#  'hotspots': [{'confidence': 65,
#                'date': datetime.datetime(2022, 12, 24, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 24, 13, 12, 1),
#                'latitude': -35.646,
#                'longitude': 142.282,
#                'surface_temperature_celcius': 32}],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.0,
#  'station': 948702,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6481357e25c02be8d1a09913'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 12, 25, 0, 0),
#  'hotspots': [{'confidence': 80,
#                'date': datetime.datetime(2022, 12, 25, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 25, 4, 29, 8),
#                'latitude': -37.708,
#                'longitude': 145.1,
#                'surface_temperature_celcius': 54}],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 50.4,
#  'station': 948702,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('6481357e25c02be8d1a09914'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2022, 12, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.5,
#  'station': 948702,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('6481357e25c02be8d1a09915'),
#  'air_temperature_celcius': 28,
#  'date': datetime.datetime(2022, 12, 27, 0, 0),
#  'hotspots': [{'confidence': 78,
#                'date': datetime.datetime(2022, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 27, 4, 16, 51),
#                'latitude': -37.966,
#                'longitude': 145.051,
#                'surface_temperature_celcius': 68},
#               {'confidence': 82,
#                'date': datetime.datetime(2022, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#                'latitude': -35.541,
#                'longitude': 143.311,
#                'surface_temperature_celcius': 63},
#               {'confidence': 67,
#                'date': datetime.datetime(2022, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#                'latitude': -35.554,
#                'longitude': 143.307,
#                'surface_temperature_celcius': 53},
#               {'confidence': 86,
#                'date': datetime.datetime(2022, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2022, 12, 27, 0, 2, 14),
#                'latitude': -35.543,
#                'longitude': 143.316,
#                'surface_temperature_celcius': 67}],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('6481357e25c02be8d1a09916'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 12, 28, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 61.1,
#  'station': 948702,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a09917'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 12, 29, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.63,
#  'precipitation_flag': 'G',
#  'relative_humidity': 59.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('6481357e25c02be8d1a09918'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 12, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'relative_humidity': 51.5,
#  'station': 948702,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6481357e25c02be8d1a09919'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 12, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('6481357e25c02be8d1a0991a'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 1, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.9,
#  'station': 948702,
#  'windspeed_knots': 8.1}

# %% [markdown]
# ### ***2. Write queries to answer the following tasks on fit3182_assignment_db and corresponding collection(s). You need to write the queries as a python program using the pymongo library in Jupyter Notebook.*** ###

# %% [markdown]
# *a.	Find climate data on 12th December 2022.*

# %%
# convert target date to datetime object
target_date = datetime.strptime('12-12-2022', '%d-%m-%Y')

# retrieve documents with matching target date
# hotspot data is not needed
result = collection.find({'date': target_date}, {'_id': 0, 'hotspots': 0})

for document in result:
    # format date to be more readable 
    document['date'] = document['date'].strftime('%d-%m-%Y')
    pprint(document)
# Out:
# {'GHI_w/m2': 156,
#  'air_temperature_celcius': 19,
#  'date': '12-12-2022',
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %% [markdown]
# *b. Find the latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.*

# %%
result = collection.aggregate([
    # flatten associative array of hotspots 
    {'$unwind': '$hotspots'},
    # filter by matching surface temperature 
    {'$match': {'hotspots.surface_temperature_celcius': {'$gte': 65, '$lte': 100}}},
    # output necessary fields only
    {'$project': {
            '_id': 0, 
            'hotspots.latitude': 1, 
            'hotspots.longitude': 1, 
            'hotspots.surface_temperature_celcius': 1, 
            'hotspots.confidence': 1
        }
    }
])

for document in result:
    pprint(document)
# Out:
# {'hotspots': {'confidence': 94,
#               'latitude': -37.2284,
#               'longitude': 147.9187,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.6572,
#               'longitude': 142.0703,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 84,
#               'latitude': -37.0193,
#               'longitude': 148.1459,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.4229,
#               'longitude': 147.027,
#               'surface_temperature_celcius': 99}}
# {'hotspots': {'confidence': 80,
#               'latitude': -37.0055,
#               'longitude': 148.1582,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 85,
#               'latitude': -37.4128,
#               'longitude': 147.0242,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 90,
#               'latitude': -34.357,
#               'longitude': 141.5361,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 93,
#               'latitude': -34.3539,
#               'longitude': 141.5547,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.9939,
#               'longitude': 148.2244,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.9959,
#               'longitude': 148.2118,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 89,
#               'latitude': -34.3654,
#               'longitude': 141.543,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 96,
#               'latitude': -34.3554,
#               'longitude': 141.5413,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 94,
#               'latitude': -34.3555,
#               'longitude': 141.5495,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.7152,
#               'longitude': 141.3853,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.0155,
#               'longitude': 148.1432,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 96,
#               'latitude': -37.6622,
#               'longitude': 142.1001,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.4523,
#               'longitude': 147.0175,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 98,
#               'latitude': -37.4261,
#               'longitude': 147.0323,
#               'surface_temperature_celcius': 83}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.3949,
#               'longitude': 147.0175,
#               'surface_temperature_celcius': 91}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.6625,
#               'longitude': 144.287,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 82,
#               'latitude': -37.8973,
#               'longitude': 143.4754,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.7805,
#               'longitude': 143.5003,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.8774,
#               'longitude': 145.8213,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.8881,
#               'longitude': 145.8229,
#               'surface_temperature_celcius': 99}}
# {'hotspots': {'confidence': 71,
#               'latitude': -37.522,
#               'longitude': 143.3874,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 91,
#               'latitude': -38.0674,
#               'longitude': 142.965,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 92,
#               'latitude': -38.0715,
#               'longitude': 142.9591,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.0693,
#               'longitude': 142.9722,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.4557,
#               'longitude': 142.2434,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.8009,
#               'longitude': 142.7259,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.8099,
#               'longitude': 142.728,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.7806,
#               'longitude': 141.5597,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 98,
#               'latitude': -34.3526,
#               'longitude': 141.6458,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.0924,
#               'longitude': 141.897,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.9452,
#               'longitude': 143.5834,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 99,
#               'latitude': -34.351,
#               'longitude': 141.6567,
#               'surface_temperature_celcius': 86}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.5012,
#               'longitude': 142.5853,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.9247,
#               'longitude': 142.8999,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 97,
#               'latitude': -35.0805,
#               'longitude': 142.4642,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 87,
#               'latitude': -37.3735,
#               'longitude': 145.886,
#               'surface_temperature_celcius': 96}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.7465,
#               'longitude': 143.3806,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.8072,
#               'longitude': 145.9738,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 96,
#               'latitude': -37.3704,
#               'longitude': 145.8942,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.297,
#               'longitude': 143.5753,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.2988,
#               'longitude': 143.5487,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.3025,
#               'longitude': 143.5714,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.383,
#               'longitude': 145.9089,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.7446,
#               'longitude': 143.4085,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 98,
#               'latitude': -37.7509,
#               'longitude': 143.4023,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 87,
#               'latitude': -37.7974,
#               'longitude': 145.9535,
#               'surface_temperature_celcius': 97}}
# {'hotspots': {'confidence': 90,
#               'latitude': -35.7657,
#               'longitude': 142.0906,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.7236,
#               'longitude': 143.3995,
#               'surface_temperature_celcius': 86}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.3046,
#               'longitude': 143.5448,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.4312,
#               'longitude': 141.2064,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.1556,
#               'longitude': 141.5904,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 89,
#               'latitude': -35.7647,
#               'longitude': 142.0858,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 90,
#               'latitude': -35.4033,
#               'longitude': 143.267,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 64,
#               'latitude': -36.6281,
#               'longitude': 142.4349,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 85,
#               'latitude': -36.111,
#               'longitude': 145.124,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.1615,
#               'longitude': 141.8728,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.1122,
#               'longitude': 142.1491,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.3735,
#               'longitude': 145.8384,
#               'surface_temperature_celcius': 95}}
# {'hotspots': {'confidence': 89,
#               'latitude': -35.4255,
#               'longitude': 143.6306,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.1955,
#               'longitude': 145.914,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 85,
#               'latitude': -35.4533,
#               'longitude': 143.2029,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.5989,
#               'longitude': 141.9771,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 66,
#               'latitude': -36.6299,
#               'longitude': 142.4234,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.1925,
#               'longitude': 145.93,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 98,
#               'latitude': -36.095,
#               'longitude': 141.7699,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.6006,
#               'longitude': 141.9657,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.0769,
#               'longitude': 141.042,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 79,
#               'latitude': -36.883,
#               'longitude': 142.1637,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 87,
#               'latitude': -36.0973,
#               'longitude': 143.4279,
#               'surface_temperature_celcius': 92}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.1819,
#               'longitude': 145.9269,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 87,
#               'latitude': -37.6387,
#               'longitude': 142.9032,
#               'surface_temperature_celcius': 88}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.6439,
#               'longitude': 142.913,
#               'surface_temperature_celcius': 83}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.3165,
#               'longitude': 147.4932,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.3158,
#               'longitude': 147.4986,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.4471,
#               'longitude': 147.6331,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.7835,
#               'longitude': 148.4138,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.4449,
#               'longitude': 147.6594,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.4323,
#               'longitude': 147.6583,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.4343,
#               'longitude': 147.6327,
#               'surface_temperature_celcius': 92}}
# {'hotspots': {'confidence': 84,
#               'latitude': -37.5816,
#               'longitude': 148.5862,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.6334,
#               'longitude': 142.2244,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 76,
#               'latitude': -37.7966,
#               'longitude': 142.3196,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 100,
#               'latitude': -35.805,
#               'longitude': 142.1326,
#               'surface_temperature_celcius': 95}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.8429,
#               'longitude': 143.8366,
#               'surface_temperature_celcius': 88}}
# {'hotspots': {'confidence': 77,
#               'latitude': -37.8062,
#               'longitude': 143.3598,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.9918,
#               'longitude': 141.8667,
#               'surface_temperature_celcius': 97}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.1104,
#               'longitude': 145.9829,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.782,
#               'longitude': 148.3844,
#               'surface_temperature_celcius': 99}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.9902,
#               'longitude': 141.879,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.745,
#               'longitude': 142.993,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.0157,
#               'longitude': 145.9414,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.777,
#               'longitude': 148.4128,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.5888,
#               'longitude': 148.5949,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 89,
#               'latitude': -34.3943,
#               'longitude': 141.7567,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 81,
#               'latitude': -36.0844,
#               'longitude': 141.4934,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.031,
#               'longitude': 145.6824,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 86,
#               'latitude': -37.5814,
#               'longitude': 148.5777,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.5788,
#               'longitude': 148.592,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.6384,
#               'longitude': 142.4075,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 94,
#               'latitude': -35.811,
#               'longitude': 142.1403,
#               'surface_temperature_celcius': 96}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.9034,
#               'longitude': 141.0013,
#               'surface_temperature_celcius': 95}}
# {'hotspots': {'confidence': 88,
#               'latitude': -37.7746,
#               'longitude': 148.3673,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 83,
#               'latitude': -37.803,
#               'longitude': 142.3151,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 96,
#               'latitude': -37.7542,
#               'longitude': 142.9949,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.3803,
#               'longitude': 145.611,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.7617,
#               'longitude': 143.081,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.8161,
#               'longitude': 142.9286,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.0387,
#               'longitude': 145.6787,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.6349,
#               'longitude': 142.2125,
#               'surface_temperature_celcius': 86}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.9018,
#               'longitude': 141.0146,
#               'surface_temperature_celcius': 100}}
# {'hotspots': {'confidence': 86,
#               'latitude': -36.6986,
#               'longitude': 142.7259,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 94,
#               'latitude': -38.0052,
#               'longitude': 142.6179,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.2168,
#               'longitude': 147.4748,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 96,
#               'latitude': -37.222,
#               'longitude': 147.4689,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.2063,
#               'longitude': 147.4713,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.2082,
#               'longitude': 147.4368,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.224,
#               'longitude': 147.4347,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 67,
#               'latitude': -37.34,
#               'longitude': 149.3668,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 99,
#               'latitude': -36.7287,
#               'longitude': 142.6017,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 91,
#               'latitude': -35.2363,
#               'longitude': 143.0004,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 100,
#               'latitude': -35.2378,
#               'longitude': 142.9864,
#               'surface_temperature_celcius': 94}}
# {'hotspots': {'confidence': 98,
#               'latitude': -35.2381,
#               'longitude': 142.994,
#               'surface_temperature_celcius': 83}}
# {'hotspots': {'confidence': 66,
#               'latitude': -37.3493,
#               'longitude': 149.3691,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.7165,
#               'longitude': 142.6155,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 94,
#               'latitude': -37.5812,
#               'longitude': 142.7374,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.5949,
#               'longitude': 142.6857,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.8247,
#               'longitude': 143.6243,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.4028,
#               'longitude': 143.6932,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.4033,
#               'longitude': 143.6884,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.8249,
#               'longitude': 143.6174,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.6823,
#               'longitude': 142.5024,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.4489,
#               'longitude': 144.7685,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.9498,
#               'longitude': 142.2012,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.1941,
#               'longitude': 143.1604,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.4142,
#               'longitude': 143.1077,
#               'surface_temperature_celcius': 97}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.1924,
#               'longitude': 143.1716,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.0295,
#               'longitude': 143.6409,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.0761,
#               'longitude': 141.0574,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 93,
#               'latitude': -35.0616,
#               'longitude': 141.4417,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.3999,
#               'longitude': 144.737,
#               'surface_temperature_celcius': 88}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.1748,
#               'longitude': 145.7582,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 99,
#               'latitude': -36.0691,
#               'longitude': 145.7797,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 90,
#               'latitude': -35.1949,
#               'longitude': 141.0622,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.91,
#               'longitude': 141.2705,
#               'surface_temperature_celcius': 96}}
# {'hotspots': {'confidence': 89,
#               'latitude': -35.8071,
#               'longitude': 142.7318,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.7787,
#               'longitude': 141.4449,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 98,
#               'latitude': -36.2948,
#               'longitude': 141.3486,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 89,
#               'latitude': -38.1561,
#               'longitude': 143.7846,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.8185,
#               'longitude': 142.5609,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.1771,
#               'longitude': 145.7451,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.027,
#               'longitude': 142.3844,
#               'surface_temperature_celcius': 95}}
# {'hotspots': {'confidence': 89,
#               'latitude': -35.7642,
#               'longitude': 143.3321,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.429,
#               'longitude': 141.5759,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.1346,
#               'longitude': 145.2196,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.0899,
#               'longitude': 141.0238,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.3823,
#               'longitude': 141.3146,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.1462,
#               'longitude': 145.2096,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.5243,
#               'longitude': 142.0839,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 98,
#               'latitude': -37.618,
#               'longitude': 143.0013,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.8867,
#               'longitude': 142.1873,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.9364,
#               'longitude': 143.4996,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.3847,
#               'longitude': 142.8935,
#               'surface_temperature_celcius': 88}}
# {'hotspots': {'confidence': 100,
#               'latitude': -35.6374,
#               'longitude': 142.3787,
#               'surface_temperature_celcius': 95}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.8835,
#               'longitude': 142.2098,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.4125,
#               'longitude': 143.1189,
#               'surface_temperature_celcius': 92}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.0669,
#               'longitude': 141.0556,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.0714,
#               'longitude': 145.7665,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.2933,
#               'longitude': 141.36,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.4591,
#               'longitude': 144.9492,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.3487,
#               'longitude': 145.5315,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.5399,
#               'longitude': 144.678,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.8158,
#               'longitude': 142.6229,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.4518,
#               'longitude': 144.7752,
#               'surface_temperature_celcius': 97}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.7903,
#               'longitude': 141.618,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.1067,
#               'longitude': 143.7948,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.1441,
#               'longitude': 145.2221,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.4816,
#               'longitude': 141.6635,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.0837,
#               'longitude': 144.2448,
#               'surface_temperature_celcius': 87}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.782,
#               'longitude': 141.8851,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.5586,
#               'longitude': 144.0423,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.5568,
#               'longitude': 144.0538,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.4538,
#               'longitude': 144.763,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.4612,
#               'longitude': 144.7775,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.7089,
#               'longitude': 143.3518,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.601,
#               'longitude': 144.6378,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.8681,
#               'longitude': 143.5186,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.1999,
#               'longitude': 143.8231,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.6171,
#               'longitude': 142.9426,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 84,
#               'latitude': -37.7587,
#               'longitude': 142.8521,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.4611,
#               'longitude': 144.9371,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.0254,
#               'longitude': 142.3959,
#               'surface_temperature_celcius': 99}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.88,
#               'longitude': 143.7233,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.8885,
#               'longitude': 143.9157,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 95,
#               'latitude': -35.0706,
#               'longitude': 141.4435,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.0795,
#               'longitude': 143.2449,
#               'surface_temperature_celcius': 91}}
# {'hotspots': {'confidence': 100,
#               'latitude': -35.1857,
#               'longitude': 141.0604,
#               'surface_temperature_celcius': 92}}
# {'hotspots': {'confidence': 100,
#               'latitude': -35.6469,
#               'longitude': 142.376,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 91,
#               'latitude': -35.6453,
#               'longitude': 142.387,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.4409,
#               'longitude': 141.6948,
#               'surface_temperature_celcius': 92}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.9174,
#               'longitude': 145.8678,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.9152,
#               'longitude': 145.8808,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.8906,
#               'longitude': 146.2035,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 100,
#               'latitude': -35.8182,
#               'longitude': 143.8739,
#               'surface_temperature_celcius': 92}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.9246,
#               'longitude': 146.2464,
#               'surface_temperature_celcius': 96}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.3313,
#               'longitude': 141.0017,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.2857,
#               'longitude': 141.3467,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.0749,
#               'longitude': 143.4058,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.4449,
#               'longitude': 140.9836,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.3972,
#               'longitude': 141.6041,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.5532,
#               'longitude': 142.5349,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.1367,
#               'longitude': 145.2071,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.1518,
#               'longitude': 144.0233,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.1418,
#               'longitude': 144.0261,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 75,
#               'latitude': -36.7499,
#               'longitude': 141.3006,
#               'surface_temperature_celcius': 99}}
# {'hotspots': {'confidence': 84,
#               'latitude': -36.7432,
#               'longitude': 141.3296,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 84,
#               'latitude': -36.7531,
#               'longitude': 141.3253,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 99,
#               'latitude': -36.7943,
#               'longitude': 143.9571,
#               'surface_temperature_celcius': 84}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.7957,
#               'longitude': 143.9652,
#               'surface_temperature_celcius': 87}}
# {'hotspots': {'confidence': 98,
#               'latitude': -36.9329,
#               'longitude': 143.7796,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 99,
#               'latitude': -35.8276,
#               'longitude': 143.7549,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 78,
#               'latitude': -35.9326,
#               'longitude': 141.958,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.6892,
#               'longitude': 145.2775,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.73,
#               'longitude': 143.935,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.8283,
#               'longitude': 143.4605,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.6527,
#               'longitude': 142.7392,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.1898,
#               'longitude': 145.0922,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.8298,
#               'longitude': 143.4483,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.6615,
#               'longitude': 144.6014,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.8238,
#               'longitude': 143.5724,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.1988,
#               'longitude': 145.0941,
#               'surface_temperature_celcius': 100}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.7651,
#               'longitude': 143.5801,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.5199,
#               'longitude': 144.7311,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.0782,
#               'longitude': 145.3625,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.3966,
#               'longitude': 141.406,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.1349,
#               'longitude': 141.9491,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.6397,
#               'longitude': 142.5968,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.6267,
#               'longitude': 142.9993,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.5871,
#               'longitude': 144.4958,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.2618,
#               'longitude': 141.8783,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.6828,
#               'longitude': 144.784,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.4843,
#               'longitude': 143.0592,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 94,
#               'latitude': -37.7274,
#               'longitude': 142.9536,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.6964,
#               'longitude': 142.8583,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 98,
#               'latitude': -38.0509,
#               'longitude': 143.9423,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.9284,
#               'longitude': 143.108,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.5701,
#               'longitude': 142.6497,
#               'surface_temperature_celcius': 94}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.7101,
#               'longitude': 142.3865,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 93,
#               'latitude': -38.1693,
#               'longitude': 143.0466,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.7128,
#               'longitude': 142.3717,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.4885,
#               'longitude': 142.0658,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 77,
#               'latitude': -36.7101,
#               'longitude': 142.981,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.0959,
#               'longitude': 143.8206,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.9594,
#               'longitude': 143.5638,
#               'surface_temperature_celcius': 87}}
# {'hotspots': {'confidence': 98,
#               'latitude': -36.5921,
#               'longitude': 144.4905,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.6787,
#               'longitude': 144.8042,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 84,
#               'latitude': -38.0423,
#               'longitude': 146.4048,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 94,
#               'latitude': -38.1224,
#               'longitude': 143.7553,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 94,
#               'latitude': -38.0792,
#               'longitude': 143.7361,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.9157,
#               'longitude': 143.3544,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 96,
#               'latitude': -37.7935,
#               'longitude': 143.1606,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.7756,
#               'longitude': 143.1388,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.7171,
#               'longitude': 142.9505,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 94,
#               'latitude': -37.7236,
#               'longitude': 142.947,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.7002,
#               'longitude': 142.9562,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.6498,
#               'longitude': 142.5997,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.5728,
#               'longitude': 142.6348,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.4352,
#               'longitude': 143.1444,
#               'surface_temperature_celcius': 96}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.5828,
#               'longitude': 144.5775,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.5987,
#               'longitude': 144.4995,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 98,
#               'latitude': -36.5262,
#               'longitude': 144.5737,
#               'surface_temperature_celcius': 84}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.6995,
#               'longitude': 142.978,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.8879,
#               'longitude': 141.6647,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 100,
#               'latitude': -35.8768,
#               'longitude': 145.4627,
#               'surface_temperature_celcius': 86}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.4899,
#               'longitude': 142.2805,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.663,
#               'longitude': 141.3038,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.092,
#               'longitude': 141.7306,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 89,
#               'latitude': -34.9023,
#               'longitude': 142.0557,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.2637,
#               'longitude': 145.3649,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.2609,
#               'longitude': 141.7999,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.91,
#               'longitude': 141.0704,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.2652,
#               'longitude': 145.3769,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.738,
#               'longitude': 142.1177,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 89,
#               'latitude': -37.876,
#               'longitude': 143.7804,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 88,
#               'latitude': -36.1546,
#               'longitude': 141.8146,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 87,
#               'latitude': -37.9091,
#               'longitude': 143.5105,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 80,
#               'latitude': -36.1559,
#               'longitude': 141.8102,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.9071,
#               'longitude': 143.538,
#               'surface_temperature_celcius': 88}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.3902,
#               'longitude': 148.2955,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.5027,
#               'longitude': 146.347,
#               'surface_temperature_celcius': 95}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.5043,
#               'longitude': 146.3299,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.1964,
#               'longitude': 144.5217,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.769,
#               'longitude': 147.94,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.1303,
#               'longitude': 146.3606,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 98,
#               'latitude': -36.1345,
#               'longitude': 146.351,
#               'surface_temperature_celcius': 84}}
# {'hotspots': {'confidence': 99,
#               'latitude': -36.1586,
#               'longitude': 145.6666,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.5847,
#               'longitude': 145.1968,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 93,
#               'latitude': -36.9111,
#               'longitude': 142.692,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.5115,
#               'longitude': 143.14,
#               'surface_temperature_celcius': 86}}
# {'hotspots': {'confidence': 86,
#               'latitude': -37.6775,
#               'longitude': 148.5131,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 87,
#               'latitude': -36.3332,
#               'longitude': 145.8594,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 70,
#               'latitude': -36.9303,
#               'longitude': 143.1034,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 83,
#               'latitude': -36.3195,
#               'longitude': 146.0601,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.5839,
#               'longitude': 143.0588,
#               'surface_temperature_celcius': 99}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.5854,
#               'longitude': 143.0462,
#               'surface_temperature_celcius': 94}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.3014,
#               'longitude': 143.203,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.1917,
#               'longitude': 147.0745,
# ...
#               'longitude': 143.4543,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 99,
#               'latitude': -38.0881,
#               'longitude': 143.9391,
#               'surface_temperature_celcius': 84}}
# {'hotspots': {'confidence': 96,
#               'latitude': -38.0866,
#               'longitude': 143.9534,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 92,
#               'latitude': -38.2391,
#               'longitude': 142.82,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.5123,
#               'longitude': 146.4007,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.3438,
#               'longitude': 141.5832,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 94,
#               'latitude': -37.4357,
#               'longitude': 142.7813,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.5867,
#               'longitude': 143.6256,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.2911,
#               'longitude': 141.1664,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.2842,
#               'longitude': 141.1741,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.7218,
#               'longitude': 141.6411,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 84,
#               'latitude': -37.3656,
#               'longitude': 141.3903,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.4179,
#               'longitude': 144.2924,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.3207,
#               'longitude': 140.9737,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 99,
#               'latitude': -36.2882,
#               'longitude': 141.1821,
#               'surface_temperature_celcius': 86}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.3153,
#               'longitude': 140.9789,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.4169,
#               'longitude': 144.2994,
#               'surface_temperature_celcius': 81}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.4671,
#               'longitude': 145.9962,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.3254,
#               'longitude': 144.3638,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.0816,
#               'longitude': 145.859,
#               'surface_temperature_celcius': 98}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.1532,
#               'longitude': 143.5527,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.0077,
#               'longitude': 141.7747,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.0828,
#               'longitude': 145.873,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.5541,
#               'longitude': 144.1321,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 91,
#               'latitude': -35.6819,
#               'longitude': 143.5275,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 90,
#               'latitude': -35.6871,
#               'longitude': 143.5235,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.1506,
#               'longitude': 143.5671,
#               'surface_temperature_celcius': 95}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.4984,
#               'longitude': 142.9739,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 96,
#               'latitude': -37.253,
#               'longitude': 144.3681,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.9396,
#               'longitude': 143.1462,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.3387,
#               'longitude': 141.7542,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.3433,
#               'longitude': 143.4369,
#               'surface_temperature_celcius': 94}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.345,
#               'longitude': 143.4256,
#               'surface_temperature_celcius': 87}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.7032,
#               'longitude': 144.0992,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.3402,
#               'longitude': 141.7429,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.5661,
#               'longitude': 142.2956,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 85,
#               'latitude': -36.5023,
#               'longitude': 143.6038,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.8616,
#               'longitude': 142.8025,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 90,
#               'latitude': -38.0372,
#               'longitude': 146.0616,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 94,
#               'latitude': -38.049,
#               'longitude': 146.0513,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 89,
#               'latitude': -35.4666,
#               'longitude': 142.0749,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 95,
#               'latitude': -36.0396,
#               'longitude': 141.7183,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.2775,
#               'longitude': 146.1026,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.0361,
#               'longitude': 146.0567,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.7746,
#               'longitude': 146.6642,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.8359,
#               'longitude': 146.6448,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 98,
#               'latitude': -37.9085,
#               'longitude': 141.1038,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 100,
#               'latitude': -38.4349,
#               'longitude': 146.3122,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 89,
#               'latitude': -38.4792,
#               'longitude': 146.3081,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.9047,
#               'longitude': 141.0945,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.7685,
#               'longitude': 142.7134,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.7801,
#               'longitude': 142.7151,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 96,
#               'latitude': -36.1002,
#               'longitude': 142.3405,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 90,
#               'latitude': -36.4325,
#               'longitude': 144.3142,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 94,
#               'latitude': -36.2693,
#               'longitude': 143.1768,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 91,
#               'latitude': -36.3774,
#               'longitude': 143.7079,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.3756,
#               'longitude': 143.7243,
#               'surface_temperature_celcius': 88}}
# {'hotspots': {'confidence': 97,
#               'latitude': -36.369,
#               'longitude': 143.7132,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.3799,
#               'longitude': 143.7149,
#               'surface_temperature_celcius': 89}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.8644,
#               'longitude': 143.4263,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 89,
#               'latitude': -38.3998,
#               'longitude': 147.064,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 94,
#               'latitude': -37.4796,
#               'longitude': 141.9403,
#               'surface_temperature_celcius': 87}}
# {'hotspots': {'confidence': 58,
#               'latitude': -37.379,
#               'longitude': 148.126,
#               'surface_temperature_celcius': 82}}
# {'hotspots': {'confidence': 62,
#               'latitude': -37.379,
#               'longitude': 148.132,
#               'surface_temperature_celcius': 78}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.396,
#               'longitude': 148.086,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.399,
#               'longitude': 148.081,
#               'surface_temperature_celcius': 84}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.401,
#               'longitude': 148.067,
#               'surface_temperature_celcius': 79}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.446,
#               'longitude': 148.102,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.406,
#               'longitude': 148.123,
#               'surface_temperature_celcius': 88}}
# {'hotspots': {'confidence': 68,
#               'latitude': -37.452,
#               'longitude': 148.115,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 64,
#               'latitude': -37.45,
#               'longitude': 148.126,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 86,
#               'latitude': -37.436,
#               'longitude': 148.088,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 73,
#               'latitude': -37.444,
#               'longitude': 148.101,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 61,
#               'latitude': -37.562,
#               'longitude': 148.05,
#               'surface_temperature_celcius': 72}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.462,
#               'longitude': 148.089,
#               'surface_temperature_celcius': 90}}
# {'hotspots': {'confidence': 88,
#               'latitude': -37.46,
#               'longitude': 148.102,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 96,
#               'latitude': -38.127,
#               'longitude': 143.82,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.294,
#               'longitude': 141.232,
#               'surface_temperature_celcius': 87}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.293,
#               'longitude': 141.245,
#               'surface_temperature_celcius': 85}}
# {'hotspots': {'confidence': 91,
#               'latitude': -37.247,
#               'longitude': 141.278,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 92,
#               'latitude': -36.098,
#               'longitude': 143.74,
#               'surface_temperature_celcius': 67}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.331,
#               'longitude': 143.122,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.477,
#               'longitude': 143.352,
#               'surface_temperature_celcius': 93}}
# {'hotspots': {'confidence': 96,
#               'latitude': -37.475,
#               'longitude': 143.365,
#               'surface_temperature_celcius': 77}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.69,
#               'longitude': 143.605,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 89,
#               'latitude': -36.94,
#               'longitude': 143.281,
#               'surface_temperature_celcius': 69}}
# {'hotspots': {'confidence': 87,
#               'latitude': -37.862,
#               'longitude': 144.175,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.945,
#               'longitude': 144.354,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celcius': 87}}
# {'hotspots': {'confidence': 97,
#               'latitude': -37.61,
#               'longitude': 149.307,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celcius': 84}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65}}
# {'hotspots': {'confidence': 100,
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 98,
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83}}
# {'hotspots': {'confidence': 99,
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76}}
# {'hotspots': {'confidence': 100,
#               'latitude': -36.282,
#               'longitude': 146.157,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 92,
#               'latitude': -37.95,
#               'longitude': 142.366,
#               'surface_temperature_celcius': 70}}
# {'hotspots': {'confidence': 93,
#               'latitude': -37.875,
#               'longitude': 142.51,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 95,
#               'latitude': -37.613,
#               'longitude': 149.305,
#               'surface_temperature_celcius': 75}}
# {'hotspots': {'confidence': 90,
#               'latitude': -37.624,
#               'longitude': 149.314,
#               'surface_temperature_celcius': 66}}
# {'hotspots': {'confidence': 93,
#               'latitude': -38.057,
#               'longitude': 144.211,
#               'surface_temperature_celcius': 73}}
# {'hotspots': {'confidence': 78,
#               'latitude': -37.966,
#               'longitude': 145.051,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 86,
#               'latitude': -35.543,
#               'longitude': 143.316,
#               'surface_temperature_celcius': 67}}

# %% [markdown]
# *c. Find date, surface temperature (°C), air temperature (°C), relative humidity and max wind speed on 15th and 16th of December 2022.*

# %%
# convert target dates to datetime objects
target_date1 = datetime.strptime('15-12-2022', '%d-%m-%Y')
target_date2 = datetime.strptime('16-12-2022', '%d-%m-%Y')

result = collection.find(
    {'$or': [{'date': target_date1}, {'date': target_date2}]},
    # output necessary fields only
    {'_id': 0, 'date': 1, 'hotspots.surface_temperature_celcius': 1, 'air_temperature_celcius': 1,
     'relative_humidity': 1, 'max_wind_speed': 1}
)


for document in result:
    pprint(document)
# Out:
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 12, 15, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 42},
#               {'surface_temperature_celcius': 36},
#               {'surface_temperature_celcius': 38},
#               {'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 43},
#               {'surface_temperature_celcius': 33},
#               {'surface_temperature_celcius': 54},
#               {'surface_temperature_celcius': 73},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 75},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 66},
#               {'surface_temperature_celcius': 56},
#               {'surface_temperature_celcius': 60},
#               {'surface_temperature_celcius': 73},
#               {'surface_temperature_celcius': 48},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 64},
#               {'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %% [markdown]
# *d. Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.*

# %%
result = collection.aggregate([
    # flatten associative array of hotspots 
    {'$unwind': '$hotspots'},
    # filter by matching confidence  
    {'$match': {'hotspots.confidence': {'$gte': 80, '$lte': 100}}},
    # output necessary fields only
    {'$project': {
            '_id': 0, 
            'hotspots.datetime': 1, 
            'air_temperature_celcius': 1, 
            'hotspots.surface_temperature_celcius': 1, 
            'hotspots.confidence': 1
        }
    }
])

for document in result:
    pprint(document)
# Out:
# {'air_temperature_celcius': 20,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 3, 6, 5, 6, 30),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 20,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 3, 6, 5, 6, 20),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 3, 7, 4, 16, 10),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 3, 9, 13, 23, 40),
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 10, 4, 48, 40),
#               'surface_temperature_celcius': 105}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 10, 4, 46, 20),
#               'surface_temperature_celcius': 109}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 3, 10, 4, 45, 30),
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 3, 10, 4, 45, 30),
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 10, 4, 43, 50),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 3, 12, 4, 33, 50),
#               'surface_temperature_celcius': 105}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 3, 12, 4, 29, 50),
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 12, 4, 28, 20),
#               'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 3, 12, 4, 28),
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 3, 12, 4, 27, 20),
#               'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 24, 40),
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 22, 20),
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 20, 50),
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 16, 30),
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 16, 20),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 14, 40),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 14, 30),
#               'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 3, 14, 4, 14, 30),
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 3, 17, 4, 48, 20),
#               'surface_temperature_celcius': 74}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 3, 17, 4, 45, 10),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 3, 17, 4, 45),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 18, 3, 50, 50),
#               'surface_temperature_celcius': 121}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 3, 18, 3, 50, 40),
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 39, 50),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#               'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 36),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 98,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 33),
#               'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#               'surface_temperature_celcius': 91}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#               'surface_temperature_celcius': 113}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 19, 4, 32, 40),
#               'surface_temperature_celcius': 106}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 3, 25, 3, 59, 50),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 3, 25, 3, 58, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 3, 25, 3, 58, 10),
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 3, 25, 3, 57, 10),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 25, 3, 57, 10),
#               'surface_temperature_celcius': 111}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 3, 25, 3, 57, 10),
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 25, 3, 56, 40),
#               'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 43, 20),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 40, 50),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 50),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 91,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 38),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 33, 40),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 33, 30),
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 33, 30),
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 32, 20),
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 30, 50),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 30, 20),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#               'surface_temperature_celcius': 74}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 98,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#               'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 30, 10),
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 28, 30),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 28, 30),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 28, 30),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 27, 40),
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 27, 20),
#               'surface_temperature_celcius': 107}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 27, 10),
#               'surface_temperature_celcius': 108}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 27),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 99,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 27),
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 3, 31, 5, 7, 10),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 3, 31, 5, 1, 20),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 3, 31, 4, 58, 30),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 3, 31, 4, 58),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 3, 31, 0, 36, 30),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 91,
#               'datetime': datetime.datetime(2022, 4, 3, 13, 17),
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 3, 13, 15, 30),
#               'surface_temperature_celcius': 40}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 3, 13, 15, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 4, 3, 13, 15, 10),
#               'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 59, 10),
#               'surface_temperature_celcius': 96}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 57, 50),
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 56, 20),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 55, 10),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 55, 10),
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 54),
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 53, 50),
#               'surface_temperature_celcius': 93}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 53, 30),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 30),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 30),
#               'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 20),
#               'surface_temperature_celcius': 115}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#               'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#               'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51, 30),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51, 30),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 98,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#               'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51),
#               'surface_temperature_celcius': 103}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#               'surface_temperature_celcius': 97}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 99,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 3, 1, 7, 20),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 4, 15, 31),
#               'surface_temperature_celcius': 44}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 15, 30, 40),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 41, 50),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 41, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 41),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 41),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 40),
#               'surface_temperature_celcius': 120}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 39, 50),
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 39, 50),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 39, 40),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 39, 40),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 39, 20),
#               'surface_temperature_celcius': 107}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 37, 10),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 36, 10),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 36, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 36),
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 35),
#               'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 34, 50),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 34),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 50),
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 40),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#               'surface_temperature_celcius': 113}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33),
#               'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 98,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'surface_temperature_celcius': 123}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'surface_temperature_celcius': 118}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 120}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 92}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 101}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 4, 4, 0, 12, 50),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 9),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 9),
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 8, 40),
#               'surface_temperature_celcius': 44}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 8, 40),
#               'surface_temperature_celcius': 47}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 7),
#               'surface_temperature_celcius': 40}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 4, 20),
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 3, 20),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 98,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 3),
#               'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 3),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 3),
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 2, 40),
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 4, 5, 13, 2, 40),
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 5, 5, 16, 50),
#               'surface_temperature_celcius': 88}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 5, 5, 15, 30),
#               'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 40, 50),
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 40, 30),
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 40, 20),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 30),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 30),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 20),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 20),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'surface_temperature_celcius': 92}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 4, 6, 13, 45, 30),
#               'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 32, 20),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 31, 10),
#               'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27, 50),
#               'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27, 50),
#               'surface_temperature_celcius': 88}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27, 10),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#               'surface_temperature_celcius': 97}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#               'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 27),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 24, 40),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 24, 20),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 24, 20),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 24),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 99,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#               'surface_temperature_celcius': 85}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 30),
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 10),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 40),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#               'surface_temperature_celcius': 103}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 91,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#               'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 10),
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 10),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 10),
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 21, 30),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 21, 10),
#               'surface_temperature_celcius': 96}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#               'surface_temperature_celcius': 115}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#               'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 91,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 104}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 100}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 4, 7, 12, 56, 50),
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 4, 7, 12, 56, 30),
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 4, 7, 12, 56, 30),
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 7, 12, 53, 40),
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 4, 7, 12, 52, 10),
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 97,
# ...
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 10, 3, 3, 58, 14),
#               'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 10, 3, 3, 58, 14),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 10, 3, 3, 58, 14),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 10, 4, 4, 41, 2),
#               'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 10, 4, 4, 41),
#               'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 10, 4, 4, 41),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 10, 4, 4, 41),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 91,
#               'datetime': datetime.datetime(2022, 10, 7, 12, 59, 33),
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 10, 10, 4, 4, 19),
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 10, 15, 4, 23, 1),
#               'surface_temperature_celcius': 87}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 99,
#               'datetime': datetime.datetime(2022, 10, 15, 4, 23, 1),
#               'surface_temperature_celcius': 85}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 10, 17, 13, 36, 12),
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 91,
#               'datetime': datetime.datetime(2022, 10, 17, 4, 10, 45),
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 10, 17, 4, 10, 32),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 2),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 10, 18, 0, 39, 2),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 10, 20, 4, 41, 19),
#               'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 10, 20, 4, 41, 19),
#               'surface_temperature_celcius': 50}}
# {'air_temperature_celcius': 12,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 10, 21, 1, 9, 55),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 12,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 10, 21, 1, 9, 54),
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 10, 26, 13, 30, 31),
#               'surface_temperature_celcius': 48}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 10, 26, 13, 30, 31),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 10, 27, 4, 47, 31),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 10, 28, 3, 52, 17),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 11, 5, 4, 41, 34),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 11, 5, 4, 41, 19),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 11, 5, 4, 41, 19),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 48),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 48),
#               'surface_temperature_celcius': 93}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 96,
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 48),
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 44),
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 44),
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 11, 11, 13, 30, 8),
#               'surface_temperature_celcius': 37}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 11, 13, 30, 8),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 11, 11, 4, 4, 25),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 89,
#               'datetime': datetime.datetime(2022, 11, 12, 0, 33, 15),
#               'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 11, 13, 3, 52, 15),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 11, 13, 3, 52, 14),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 11, 14, 4, 35, 4),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 85,
#               'datetime': datetime.datetime(2022, 11, 21, 0, 27, 21),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 11, 22, 3, 46),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 88,
#               'datetime': datetime.datetime(2022, 11, 22, 3, 46),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 11, 23, 4, 28, 59),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 11, 23, 4, 28, 59),
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'surface_temperature_celcius': 87}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 97,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 99,
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'surface_temperature_celcius': 84}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'surface_temperature_celcius': 38}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 14),
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 35),
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 98,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 99,
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 12, 8, 13, 11, 44),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 12, 8, 13, 11, 44),
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': datetime.datetime(2022, 12, 8, 13, 11, 43),
#               'surface_temperature_celcius': 52}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 87,
#               'datetime': datetime.datetime(2022, 12, 9, 0, 14, 34),
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': datetime.datetime(2022, 12, 9, 0, 14, 34),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 12, 9, 0, 14, 33),
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 12, 9, 0, 14, 33),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 83,
#               'datetime': datetime.datetime(2022, 12, 13, 4, 4, 19),
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 12, 14, 4, 47, 25),
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 92,
#               'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 94,
#               'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 12, 16, 4, 35, 13),
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 84,
#               'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 95,
#               'datetime': datetime.datetime(2022, 12, 16, 4, 34, 58),
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 90,
#               'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 93,
#               'datetime': datetime.datetime(2022, 12, 16, 0, 21, 12),
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 80,
#               'datetime': datetime.datetime(2022, 12, 25, 4, 29, 8),
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 82,
#               'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 86,
#               'datetime': datetime.datetime(2022, 12, 27, 0, 2, 14),
#               'surface_temperature_celcius': 67}}

# %% [markdown]
# *e.	Find the top 10 records with the highest surface temperature (°C).*

# %%
result = collection.aggregate([
    # flatten associative array of hotspots 
    {'$unwind': '$hotspots'},
    # sort by surface temperature in decreasing order
    {'$sort': {'hotspots.surface_temperature_celcius': -1}},
    # retrieve top 10 records only
    {'$limit': 10}
])


for document in result:
    pprint(document)
# Out:
# {'GHI_w/m2': 122,
#  '_id': ObjectId('6481357e25c02be8d1a09818'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2022, 4, 18, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 4, 18, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 18, 4, 52),
#               'latitude': -38.1665,
#               'longitude': 143.062,
#               'surface_temperature_celcius': 124},
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('6481357e25c02be8d1a0980a'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'latitude': -36.343,
#               'longitude': 142.1986,
#               'surface_temperature_celcius': 123},
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 121,
#  '_id': ObjectId('6481357e25c02be8d1a09825'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2022, 5, 1, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 5, 1, 0, 0),
#               'datetime': datetime.datetime(2022, 5, 1, 4, 14, 20),
#               'latitude': -36.9318,
#               'longitude': 143.0907,
#               'surface_temperature_celcius': 122},
#  'max_wind_speed': 20.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('6481357e25c02be8d1a097f9'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2022, 3, 18, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 3, 18, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 18, 3, 50, 50),
#               'latitude': -37.017,
#               'longitude': 148.1297,
#               'surface_temperature_celcius': 121},
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('6481357e25c02be8d1a0980a'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'latitude': -36.3521,
#               'longitude': 142.2008,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 132,
#  '_id': ObjectId('6481357e25c02be8d1a09813'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 4, 13, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 4, 13, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 13, 4, 28, 10),
#               'latitude': -37.0745,
#               'longitude': 141.0692,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 81,
#  '_id': ObjectId('6481357e25c02be8d1a09831'),
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2022, 5, 13, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 5, 13, 0, 0),
#               'datetime': datetime.datetime(2022, 5, 13, 4, 40, 20),
#               'latitude': -34.9938,
#               'longitude': 141.876,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('6481357e25c02be8d1a09818'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2022, 4, 18, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 4, 18, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 18, 4, 44, 50),
#               'latitude': -37.8326,
#               'longitude': 143.4999,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('6481357e25c02be8d1a0980a'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 4, 4, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 40),
#               'latitude': -36.1057,
#               'longitude': 141.7608,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('6481357e25c02be8d1a09828'),
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2022, 5, 4, 0, 0),
#  'hotspots': {'confidence': 100,
#               'date': datetime.datetime(2022, 5, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 5, 4, 4, 44, 50),
#               'latitude': -36.4057,
#               'longitude': 140.9806,
#               'surface_temperature_celcius': 119},
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %% [markdown]
# *f. Find the number of fires each day. You are required to only display the total number of fires and the date in the output.*

# %%
result = collection.aggregate([
    {'$project': {'_id': 0, 'date': 1, 'number_of_fires': {'$size': '$hotspots'}}}
])

for document in result:
    # format date to be more readable 
    document['date'] = document['date'].strftime('%d-%m-%Y')
    pprint(document)
# Out:
# {'date': '31-12-2021', 'number_of_fires': 0}
# {'date': '02-01-2022', 'number_of_fires': 0}
# {'date': '03-01-2022', 'number_of_fires': 0}
# {'date': '04-01-2022', 'number_of_fires': 0}
# {'date': '05-01-2022', 'number_of_fires': 0}
# {'date': '06-01-2022', 'number_of_fires': 0}
# {'date': '07-01-2022', 'number_of_fires': 0}
# {'date': '08-01-2022', 'number_of_fires': 0}
# {'date': '09-01-2022', 'number_of_fires': 0}
# {'date': '10-01-2022', 'number_of_fires': 0}
# {'date': '11-01-2022', 'number_of_fires': 0}
# {'date': '12-01-2022', 'number_of_fires': 0}
# {'date': '13-01-2022', 'number_of_fires': 0}
# {'date': '14-01-2022', 'number_of_fires': 0}
# {'date': '15-01-2022', 'number_of_fires': 0}
# {'date': '16-01-2022', 'number_of_fires': 0}
# {'date': '17-01-2022', 'number_of_fires': 0}
# {'date': '18-01-2022', 'number_of_fires': 0}
# {'date': '19-01-2022', 'number_of_fires': 0}
# {'date': '20-01-2022', 'number_of_fires': 0}
# {'date': '21-01-2022', 'number_of_fires': 0}
# {'date': '22-01-2022', 'number_of_fires': 0}
# {'date': '23-01-2022', 'number_of_fires': 0}
# {'date': '24-01-2022', 'number_of_fires': 0}
# {'date': '25-01-2022', 'number_of_fires': 0}
# {'date': '26-01-2022', 'number_of_fires': 0}
# {'date': '27-01-2022', 'number_of_fires': 0}
# {'date': '28-01-2022', 'number_of_fires': 0}
# {'date': '29-01-2022', 'number_of_fires': 0}
# {'date': '30-01-2022', 'number_of_fires': 0}
# {'date': '31-01-2022', 'number_of_fires': 0}
# {'date': '01-02-2022', 'number_of_fires': 0}
# {'date': '02-02-2022', 'number_of_fires': 0}
# {'date': '03-02-2022', 'number_of_fires': 0}
# {'date': '04-02-2022', 'number_of_fires': 0}
# {'date': '05-02-2022', 'number_of_fires': 0}
# {'date': '06-02-2022', 'number_of_fires': 0}
# {'date': '07-02-2022', 'number_of_fires': 0}
# {'date': '08-02-2022', 'number_of_fires': 0}
# {'date': '09-02-2022', 'number_of_fires': 0}
# {'date': '10-02-2022', 'number_of_fires': 0}
# {'date': '11-02-2022', 'number_of_fires': 0}
# {'date': '12-02-2022', 'number_of_fires': 0}
# {'date': '13-02-2022', 'number_of_fires': 0}
# {'date': '14-02-2022', 'number_of_fires': 0}
# {'date': '15-02-2022', 'number_of_fires': 0}
# {'date': '16-02-2022', 'number_of_fires': 0}
# {'date': '17-02-2022', 'number_of_fires': 0}
# {'date': '18-02-2022', 'number_of_fires': 0}
# {'date': '19-02-2022', 'number_of_fires': 0}
# {'date': '20-02-2022', 'number_of_fires': 0}
# {'date': '21-02-2022', 'number_of_fires': 0}
# {'date': '22-02-2022', 'number_of_fires': 0}
# {'date': '23-02-2022', 'number_of_fires': 0}
# {'date': '24-02-2022', 'number_of_fires': 0}
# {'date': '25-02-2022', 'number_of_fires': 0}
# {'date': '26-02-2022', 'number_of_fires': 0}
# {'date': '27-02-2022', 'number_of_fires': 0}
# {'date': '28-02-2022', 'number_of_fires': 0}
# {'date': '01-03-2022', 'number_of_fires': 0}
# {'date': '02-03-2022', 'number_of_fires': 0}
# {'date': '03-03-2022', 'number_of_fires': 0}
# {'date': '04-03-2022', 'number_of_fires': 0}
# {'date': '05-03-2022', 'number_of_fires': 0}
# {'date': '06-03-2022', 'number_of_fires': 2}
# {'date': '07-03-2022', 'number_of_fires': 1}
# {'date': '08-03-2022', 'number_of_fires': 2}
# {'date': '09-03-2022', 'number_of_fires': 3}
# {'date': '10-03-2022', 'number_of_fires': 8}
# {'date': '11-03-2022', 'number_of_fires': 0}
# {'date': '12-03-2022', 'number_of_fires': 5}
# {'date': '13-03-2022', 'number_of_fires': 2}
# {'date': '14-03-2022', 'number_of_fires': 10}
# {'date': '15-03-2022', 'number_of_fires': 7}
# {'date': '16-03-2022', 'number_of_fires': 0}
# {'date': '17-03-2022', 'number_of_fires': 6}
# {'date': '18-03-2022', 'number_of_fires': 3}
# {'date': '19-03-2022', 'number_of_fires': 21}
# {'date': '20-03-2022', 'number_of_fires': 0}
# {'date': '21-03-2022', 'number_of_fires': 0}
# {'date': '22-03-2022', 'number_of_fires': 0}
# {'date': '23-03-2022', 'number_of_fires': 0}
# {'date': '24-03-2022', 'number_of_fires': 2}
# {'date': '25-03-2022', 'number_of_fires': 13}
# {'date': '26-03-2022', 'number_of_fires': 17}
# {'date': '27-03-2022', 'number_of_fires': 0}
# {'date': '28-03-2022', 'number_of_fires': 54}
# {'date': '29-03-2022', 'number_of_fires': 1}
# {'date': '30-03-2022', 'number_of_fires': 0}
# {'date': '31-03-2022', 'number_of_fires': 22}
# {'date': '01-04-2022', 'number_of_fires': 7}
# {'date': '02-04-2022', 'number_of_fires': 5}
# {'date': '03-04-2022', 'number_of_fires': 72}
# {'date': '04-04-2022', 'number_of_fires': 89}
# {'date': '05-04-2022', 'number_of_fires': 49}
# {'date': '06-04-2022', 'number_of_fires': 118}
# {'date': '07-04-2022', 'number_of_fires': 39}
# {'date': '08-04-2022', 'number_of_fires': 20}
# {'date': '09-04-2022', 'number_of_fires': 0}
# {'date': '10-04-2022', 'number_of_fires': 0}
# {'date': '11-04-2022', 'number_of_fires': 24}
# {'date': '12-04-2022', 'number_of_fires': 69}
# {'date': '13-04-2022', 'number_of_fires': 357}
# {'date': '14-04-2022', 'number_of_fires': 18}
# {'date': '15-04-2022', 'number_of_fires': 69}
# {'date': '16-04-2022', 'number_of_fires': 18}
# {'date': '17-04-2022', 'number_of_fires': 38}
# {'date': '18-04-2022', 'number_of_fires': 325}
# {'date': '19-04-2022', 'number_of_fires': 50}
# {'date': '20-04-2022', 'number_of_fires': 31}
# {'date': '21-04-2022', 'number_of_fires': 0}
# {'date': '22-04-2022', 'number_of_fires': 2}
# {'date': '23-04-2022', 'number_of_fires': 19}
# {'date': '24-04-2022', 'number_of_fires': 8}
# {'date': '25-04-2022', 'number_of_fires': 3}
# {'date': '26-04-2022', 'number_of_fires': 1}
# {'date': '27-04-2022', 'number_of_fires': 0}
# {'date': '28-04-2022', 'number_of_fires': 0}
# {'date': '29-04-2022', 'number_of_fires': 3}
# {'date': '30-04-2022', 'number_of_fires': 0}
# {'date': '01-05-2022', 'number_of_fires': 20}
# {'date': '02-05-2022', 'number_of_fires': 10}
# {'date': '03-05-2022', 'number_of_fires': 64}
# {'date': '04-05-2022', 'number_of_fires': 135}
# {'date': '05-05-2022', 'number_of_fires': 31}
# {'date': '06-05-2022', 'number_of_fires': 17}
# {'date': '07-05-2022', 'number_of_fires': 3}
# {'date': '08-05-2022', 'number_of_fires': 24}
# {'date': '09-05-2022', 'number_of_fires': 13}
# {'date': '10-05-2022', 'number_of_fires': 114}
# {'date': '11-05-2022', 'number_of_fires': 19}
# {'date': '12-05-2022', 'number_of_fires': 10}
# {'date': '13-05-2022', 'number_of_fires': 54}
# {'date': '14-05-2022', 'number_of_fires': 1}
# {'date': '15-05-2022', 'number_of_fires': 102}
# {'date': '16-05-2022', 'number_of_fires': 3}
# {'date': '17-05-2022', 'number_of_fires': 1}
# {'date': '18-05-2022', 'number_of_fires': 7}
# {'date': '19-05-2022', 'number_of_fires': 0}
# {'date': '20-05-2022', 'number_of_fires': 0}
# {'date': '21-05-2022', 'number_of_fires': 0}
# {'date': '22-05-2022', 'number_of_fires': 33}
# {'date': '23-05-2022', 'number_of_fires': 5}
# {'date': '24-05-2022', 'number_of_fires': 3}
# {'date': '25-05-2022', 'number_of_fires': 0}
# {'date': '26-05-2022', 'number_of_fires': 4}
# {'date': '27-05-2022', 'number_of_fires': 0}
# {'date': '28-05-2022', 'number_of_fires': 0}
# {'date': '29-05-2022', 'number_of_fires': 0}
# {'date': '30-05-2022', 'number_of_fires': 0}
# {'date': '31-05-2022', 'number_of_fires': 0}
# {'date': '01-06-2022', 'number_of_fires': 2}
# {'date': '02-06-2022', 'number_of_fires': 11}
# {'date': '03-06-2022', 'number_of_fires': 2}
# {'date': '04-06-2022', 'number_of_fires': 9}
# {'date': '05-06-2022', 'number_of_fires': 0}
# {'date': '06-06-2022', 'number_of_fires': 0}
# {'date': '07-06-2022', 'number_of_fires': 14}
# {'date': '08-06-2022', 'number_of_fires': 0}
# {'date': '09-06-2022', 'number_of_fires': 3}
# {'date': '10-06-2022', 'number_of_fires': 0}
# {'date': '11-06-2022', 'number_of_fires': 2}
# {'date': '12-06-2022', 'number_of_fires': 0}
# {'date': '13-06-2022', 'number_of_fires': 1}
# {'date': '14-06-2022', 'number_of_fires': 4}
# {'date': '15-06-2022', 'number_of_fires': 0}
# {'date': '16-06-2022', 'number_of_fires': 2}
# {'date': '17-06-2022', 'number_of_fires': 0}
# {'date': '18-06-2022', 'number_of_fires': 2}
# {'date': '19-06-2022', 'number_of_fires': 0}
# {'date': '20-06-2022', 'number_of_fires': 6}
# {'date': '21-06-2022', 'number_of_fires': 0}
# {'date': '22-06-2022', 'number_of_fires': 1}
# {'date': '23-06-2022', 'number_of_fires': 0}
# {'date': '24-06-2022', 'number_of_fires': 0}
# {'date': '25-06-2022', 'number_of_fires': 0}
# {'date': '26-06-2022', 'number_of_fires': 0}
# {'date': '27-06-2022', 'number_of_fires': 0}
# {'date': '28-06-2022', 'number_of_fires': 0}
# {'date': '29-06-2022', 'number_of_fires': 0}
# {'date': '30-06-2022', 'number_of_fires': 6}
# {'date': '01-07-2022', 'number_of_fires': 4}
# {'date': '02-07-2022', 'number_of_fires': 8}
# {'date': '03-07-2022', 'number_of_fires': 0}
# {'date': '04-07-2022', 'number_of_fires': 1}
# {'date': '05-07-2022', 'number_of_fires': 1}
# {'date': '06-07-2022', 'number_of_fires': 3}
# {'date': '07-07-2022', 'number_of_fires': 0}
# {'date': '08-07-2022', 'number_of_fires': 0}
# {'date': '09-07-2022', 'number_of_fires': 0}
# {'date': '10-07-2022', 'number_of_fires': 0}
# {'date': '11-07-2022', 'number_of_fires': 0}
# {'date': '12-07-2022', 'number_of_fires': 0}
# {'date': '13-07-2022', 'number_of_fires': 0}
# {'date': '14-07-2022', 'number_of_fires': 2}
# {'date': '15-07-2022', 'number_of_fires': 0}
# {'date': '16-07-2022', 'number_of_fires': 0}
# {'date': '17-07-2022', 'number_of_fires': 0}
# {'date': '18-07-2022', 'number_of_fires': 0}
# {'date': '19-07-2022', 'number_of_fires': 0}
# {'date': '20-07-2022', 'number_of_fires': 0}
# {'date': '21-07-2022', 'number_of_fires': 0}
# {'date': '22-07-2022', 'number_of_fires': 0}
# {'date': '23-07-2022', 'number_of_fires': 0}
# {'date': '24-07-2022', 'number_of_fires': 0}
# {'date': '25-07-2022', 'number_of_fires': 0}
# {'date': '26-07-2022', 'number_of_fires': 0}
# {'date': '27-07-2022', 'number_of_fires': 0}
# {'date': '28-07-2022', 'number_of_fires': 0}
# {'date': '29-07-2022', 'number_of_fires': 2}
# {'date': '30-07-2022', 'number_of_fires': 0}
# {'date': '31-07-2022', 'number_of_fires': 2}
# {'date': '01-08-2022', 'number_of_fires': 2}
# {'date': '02-08-2022', 'number_of_fires': 2}
# {'date': '03-08-2022', 'number_of_fires': 0}
# {'date': '04-08-2022', 'number_of_fires': 0}
# {'date': '05-08-2022', 'number_of_fires': 1}
# {'date': '06-08-2022', 'number_of_fires': 0}
# {'date': '07-08-2022', 'number_of_fires': 0}
# {'date': '08-08-2022', 'number_of_fires': 0}
# {'date': '09-08-2022', 'number_of_fires': 0}
# {'date': '10-08-2022', 'number_of_fires': 1}
# {'date': '11-08-2022', 'number_of_fires': 0}
# {'date': '12-08-2022', 'number_of_fires': 0}
# {'date': '13-08-2022', 'number_of_fires': 9}
# {'date': '14-08-2022', 'number_of_fires': 5}
# {'date': '15-08-2022', 'number_of_fires': 0}
# {'date': '16-08-2022', 'number_of_fires': 0}
# {'date': '17-08-2022', 'number_of_fires': 0}
# {'date': '18-08-2022', 'number_of_fires': 0}
# {'date': '19-08-2022', 'number_of_fires': 0}
# {'date': '20-08-2022', 'number_of_fires': 0}
# {'date': '21-08-2022', 'number_of_fires': 0}
# {'date': '22-08-2022', 'number_of_fires': 0}
# {'date': '23-08-2022', 'number_of_fires': 0}
# {'date': '24-08-2022', 'number_of_fires': 0}
# {'date': '25-08-2022', 'number_of_fires': 0}
# {'date': '26-08-2022', 'number_of_fires': 0}
# {'date': '27-08-2022', 'number_of_fires': 0}
# {'date': '28-08-2022', 'number_of_fires': 0}
# {'date': '29-08-2022', 'number_of_fires': 0}
# {'date': '30-08-2022', 'number_of_fires': 0}
# {'date': '31-08-2022', 'number_of_fires': 0}
# {'date': '01-09-2022', 'number_of_fires': 0}
# {'date': '02-09-2022', 'number_of_fires': 0}
# {'date': '03-09-2022', 'number_of_fires': 0}
# {'date': '04-09-2022', 'number_of_fires': 0}
# {'date': '05-09-2022', 'number_of_fires': 0}
# {'date': '06-09-2022', 'number_of_fires': 0}
# {'date': '07-09-2022', 'number_of_fires': 0}
# {'date': '08-09-2022', 'number_of_fires': 0}
# {'date': '09-09-2022', 'number_of_fires': 0}
# {'date': '10-09-2022', 'number_of_fires': 4}
# {'date': '11-09-2022', 'number_of_fires': 0}
# {'date': '12-09-2022', 'number_of_fires': 0}
# {'date': '13-09-2022', 'number_of_fires': 0}
# {'date': '14-09-2022', 'number_of_fires': 0}
# {'date': '15-09-2022', 'number_of_fires': 0}
# {'date': '16-09-2022', 'number_of_fires': 0}
# {'date': '17-09-2022', 'number_of_fires': 0}
# {'date': '18-09-2022', 'number_of_fires': 0}
# {'date': '19-09-2022', 'number_of_fires': 0}
# {'date': '20-09-2022', 'number_of_fires': 5}
# {'date': '21-09-2022', 'number_of_fires': 2}
# {'date': '22-09-2022', 'number_of_fires': 1}
# {'date': '23-09-2022', 'number_of_fires': 23}
# {'date': '24-09-2022', 'number_of_fires': 28}
# {'date': '25-09-2022', 'number_of_fires': 0}
# {'date': '26-09-2022', 'number_of_fires': 1}
# {'date': '27-09-2022', 'number_of_fires': 7}
# {'date': '28-09-2022', 'number_of_fires': 0}
# {'date': '29-09-2022', 'number_of_fires': 2}
# {'date': '30-09-2022', 'number_of_fires': 0}
# {'date': '01-10-2022', 'number_of_fires': 8}
# {'date': '02-10-2022', 'number_of_fires': 7}
# {'date': '03-10-2022', 'number_of_fires': 18}
# {'date': '04-10-2022', 'number_of_fires': 5}
# {'date': '05-10-2022', 'number_of_fires': 0}
# {'date': '06-10-2022', 'number_of_fires': 2}
# {'date': '07-10-2022', 'number_of_fires': 1}
# {'date': '08-10-2022', 'number_of_fires': 1}
# {'date': '09-10-2022', 'number_of_fires': 1}
# {'date': '10-10-2022', 'number_of_fires': 3}
# {'date': '11-10-2022', 'number_of_fires': 0}
# {'date': '12-10-2022', 'number_of_fires': 0}
# {'date': '13-10-2022', 'number_of_fires': 0}
# {'date': '14-10-2022', 'number_of_fires': 0}
# {'date': '15-10-2022', 'number_of_fires': 3}
# {'date': '16-10-2022', 'number_of_fires': 1}
# {'date': '17-10-2022', 'number_of_fires': 5}
# {'date': '18-10-2022', 'number_of_fires': 6}
# {'date': '19-10-2022', 'number_of_fires': 0}
# {'date': '20-10-2022', 'number_of_fires': 3}
# {'date': '21-10-2022', 'number_of_fires': 4}
# {'date': '22-10-2022', 'number_of_fires': 0}
# {'date': '23-10-2022', 'number_of_fires': 1}
# {'date': '24-10-2022', 'number_of_fires': 0}
# {'date': '25-10-2022', 'number_of_fires': 0}
# {'date': '26-10-2022', 'number_of_fires': 5}
# {'date': '27-10-2022', 'number_of_fires': 5}
# {'date': '28-10-2022', 'number_of_fires': 1}
# {'date': '29-10-2022', 'number_of_fires': 0}
# {'date': '30-10-2022', 'number_of_fires': 0}
# {'date': '31-10-2022', 'number_of_fires': 0}
# {'date': '01-11-2022', 'number_of_fires': 0}
# {'date': '02-11-2022', 'number_of_fires': 0}
# {'date': '03-11-2022', 'number_of_fires': 0}
# {'date': '04-11-2022', 'number_of_fires': 0}
# {'date': '05-11-2022', 'number_of_fires': 4}
# {'date': '06-11-2022', 'number_of_fires': 0}
# {'date': '07-11-2022', 'number_of_fires': 0}
# {'date': '08-11-2022', 'number_of_fires': 2}
# {'date': '09-11-2022', 'number_of_fires': 10}
# {'date': '10-11-2022', 'number_of_fires': 0}
# {'date': '11-11-2022', 'number_of_fires': 4}
# {'date': '12-11-2022', 'number_of_fires': 5}
# {'date': '13-11-2022', 'number_of_fires': 5}
# {'date': '14-11-2022', 'number_of_fires': 3}
# {'date': '15-11-2022', 'number_of_fires': 0}
# {'date': '16-11-2022', 'number_of_fires': 0}
# {'date': '17-11-2022', 'number_of_fires': 0}
# {'date': '18-11-2022', 'number_of_fires': 0}
# {'date': '19-11-2022', 'number_of_fires': 0}
# {'date': '20-11-2022', 'number_of_fires': 0}
# {'date': '21-11-2022', 'number_of_fires': 1}
# {'date': '22-11-2022', 'number_of_fires': 2}
# {'date': '23-11-2022', 'number_of_fires': 5}
# {'date': '24-11-2022', 'number_of_fires': 0}
# {'date': '25-11-2022', 'number_of_fires': 0}
# {'date': '26-11-2022', 'number_of_fires': 0}
# {'date': '27-11-2022', 'number_of_fires': 0}
# {'date': '28-11-2022', 'number_of_fires': 1}
# {'date': '29-11-2022', 'number_of_fires': 8}
# {'date': '30-11-2022', 'number_of_fires': 31}
# {'date': '01-12-2022', 'number_of_fires': 0}
# {'date': '02-12-2022', 'number_of_fires': 0}
# {'date': '03-12-2022', 'number_of_fires': 0}
# {'date': '04-12-2022', 'number_of_fires': 0}
# {'date': '05-12-2022', 'number_of_fires': 0}
# {'date': '06-12-2022', 'number_of_fires': 0}
# {'date': '07-12-2022', 'number_of_fires': 0}
# {'date': '08-12-2022', 'number_of_fires': 5}
# {'date': '09-12-2022', 'number_of_fires': 4}
# {'date': '10-12-2022', 'number_of_fires': 2}
# {'date': '11-12-2022', 'number_of_fires': 0}
# {'date': '12-12-2022', 'number_of_fires': 1}
# {'date': '13-12-2022', 'number_of_fires': 1}
# {'date': '14-12-2022', 'number_of_fires': 1}
# {'date': '15-12-2022', 'number_of_fires': 4}
# {'date': '16-12-2022', 'number_of_fires': 15}
# {'date': '17-12-2022', 'number_of_fires': 0}
# {'date': '18-12-2022', 'number_of_fires': 0}
# {'date': '19-12-2022', 'number_of_fires': 0}
# {'date': '20-12-2022', 'number_of_fires': 0}
# {'date': '21-12-2022', 'number_of_fires': 1}
# {'date': '22-12-2022', 'number_of_fires': 0}
# {'date': '23-12-2022', 'number_of_fires': 0}
# {'date': '24-12-2022', 'number_of_fires': 1}
# {'date': '25-12-2022', 'number_of_fires': 1}
# {'date': '26-12-2022', 'number_of_fires': 0}
# {'date': '27-12-2022', 'number_of_fires': 4}
# {'date': '28-12-2022', 'number_of_fires': 0}
# {'date': '29-12-2022', 'number_of_fires': 0}
# {'date': '30-12-2022', 'number_of_fires': 0}
# {'date': '31-12-2022', 'number_of_fires': 0}
# {'date': '01-01-2023', 'number_of_fires': 0}

# %% [markdown]
# *g. Find the records of fires where the confidence is below 70.*

# %%
result = collection.aggregate([
    # flatten associative array of hotspots 
    {'$unwind': '$hotspots'},
    # filter by matching confidence 
    {'$match': {'hotspots.confidence': {'$lt': 70}}},
    # output fire records only
    {'$project': {'_id': 0, 'hotspots': 1}}
])

for document in result:
    pprint(document)
# Out:
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 3, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 8, 4, 51),
#               'latitude': -37.7885,
#               'longitude': 141.9352,
#               'surface_temperature_celcius': 55}}
# {'hotspots': {'confidence': 54,
#               'date': datetime.datetime(2022, 3, 9, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 9, 3, 57),
#               'latitude': -37.7171,
#               'longitude': 147.5866,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 55,
#               'date': datetime.datetime(2022, 3, 10, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 10, 4, 43),
#               'latitude': -36.2544,
#               'longitude': 148.0353,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 54,
#               'date': datetime.datetime(2022, 3, 10, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 10, 4, 42, 30),
#               'latitude': -37.2197,
#               'longitude': 147.9621,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 3, 13, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 13, 23, 58, 50),
#               'latitude': -37.0286,
#               'longitude': 148.155,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 3, 13, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 13, 12, 57),
#               'latitude': -37.0316,
#               'longitude': 148.1519,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 3, 15, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#               'latitude': -37.4075,
#               'longitude': 147.0233,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 3, 15, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 15, 0, 42, 50),
#               'latitude': -37.0228,
#               'longitude': 148.1281,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 3, 15, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 15, 0, 42, 40),
#               'latitude': -37.002,
#               'longitude': 148.2055,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 3, 18, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 18, 13, 16, 50),
#               'latitude': -37.4313,
#               'longitude': 147.0343,
#               'surface_temperature_celcius': 37}}
# {'hotspots': {'confidence': 58,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#               'latitude': -37.9164,
#               'longitude': 143.4866,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 39, 20),
#               'latitude': -37.9257,
#               'longitude': 143.4891,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 36),
#               'latitude': -37.3982,
#               'longitude': 147.0001,
#               'surface_temperature_celcius': 58}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 35),
#               'latitude': -37.4023,
#               'longitude': 147.0394,
#               'surface_temperature_celcius': 56}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 33, 50),
#               'latitude': -37.4336,
#               'longitude': 147.0534,
#               'surface_temperature_celcius': 51}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 33, 30),
#               'latitude': -37.4003,
#               'longitude': 147.0448,
#               'surface_temperature_celcius': 55}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 33, 30),
#               'latitude': -37.9184,
#               'longitude': 143.4745,
#               'surface_temperature_celcius': 55}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 33, 10),
#               'latitude': -37.3911,
#               'longitude': 147.037,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 4, 32, 50),
#               'latitude': -37.9277,
#               'longitude': 143.477,
#               'surface_temperature_celcius': 55}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 19, 0, 12, 50),
#               'latitude': -37.3942,
#               'longitude': 147.0455,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 3, 24, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 24, 4, 58),
#               'latitude': -37.1603,
#               'longitude': 142.8088,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 55,
#               'date': datetime.datetime(2022, 3, 24, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 24, 4, 56, 10),
#               'latitude': -37.1684,
#               'longitude': 142.8183,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 3, 25, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 25, 4, 3, 10),
#               'latitude': -37.8992,
#               'longitude': 143.4534,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 57,
#               'date': datetime.datetime(2022, 3, 25, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 25, 3, 56, 40),
#               'latitude': -37.9022,
#               'longitude': 143.4607,
#               'surface_temperature_celcius': 57}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 3, 26, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 26, 4, 41, 10),
#               'latitude': -38.1131,
#               'longitude': 143.7173,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 3, 26, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'latitude': -37.8469,
#               'longitude': 143.5343,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 3, 26, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 26, 4, 39, 10),
#               'latitude': -37.1956,
#               'longitude': 141.0252,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 3, 28, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 28, 4, 29, 30),
#               'latitude': -37.6195,
#               'longitude': 143.4212,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 3, 28, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'latitude': -37.6376,
#               'longitude': 143.4255,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 3, 28, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'latitude': -36.4422,
#               'longitude': 141.4172,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 55,
#               'date': datetime.datetime(2022, 3, 28, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 28, 4, 26, 50),
#               'latitude': -34.342,
#               'longitude': 141.6548,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 3, 29, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 29, 0, 48, 40),
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 31, 4, 57, 50),
#               'latitude': -36.1649,
#               'longitude': 145.9352,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 31, 4, 57, 40),
#               'latitude': -36.0436,
#               'longitude': 145.7964,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#               'latitude': -36.7134,
#               'longitude': 145.2151,
#               'surface_temperature_celcius': 38}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#               'latitude': -36.7028,
#               'longitude': 145.2519,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#               'latitude': -37.561,
#               'longitude': 143.242,
#               'surface_temperature_celcius': 38}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 31, 4, 57, 10),
#               'latitude': -37.982,
#               'longitude': 143.6422,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'datetime': datetime.datetime(2022, 3, 31, 0, 36, 30),
#               'latitude': -34.2568,
#               'longitude': 141.64,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 58,
#               'date': datetime.datetime(2022, 4, 1, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 1, 4, 2, 40),
#               'latitude': -36.2044,
#               'longitude': 145.7706,
#               'surface_temperature_celcius': 51}}
# {'hotspots': {'confidence': 57,
#               'date': datetime.datetime(2022, 4, 1, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 1, 4, 2, 40),
#               'latitude': -36.5245,
#               'longitude': 143.1556,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 1, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 1, 4, 2, 40),
#               'latitude': -36.1002,
#               'longitude': 147.6494,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 2, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 2, 4, 53, 30),
#               'latitude': -36.3872,
#               'longitude': 145.3858,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 2, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 2, 4, 45, 10),
#               'latitude': -36.494,
#               'longitude': 145.4522,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 2, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 2, 0, 24, 50),
#               'latitude': -37.324,
#               'longitude': 146.1647,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 53, 50),
#               'latitude': -37.8668,
#               'longitude': 143.0472,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 53, 40),
#               'latitude': -37.7602,
#               'longitude': 143.382,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 53, 30),
#               'latitude': -37.7885,
#               'longitude': 142.9509,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 52, 10),
#               'latitude': -37.8717,
#               'longitude': 143.2566,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 51, 10),
#               'latitude': -37.8011,
#               'longitude': 144.7343,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#               'latitude': -37.0241,
#               'longitude': 141.5163,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#               'latitude': -37.2912,
#               'longitude': 143.543,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#               'latitude': -37.313,
#               'longitude': 146.1561,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 50),
#               'latitude': -38.0226,
#               'longitude': 143.6739,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'latitude': -37.8089,
#               'longitude': 145.9555,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'latitude': -37.9009,
#               'longitude': 143.6217,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'latitude': -37.7836,
#               'longitude': 142.9437,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'latitude': -37.0484,
#               'longitude': 141.6245,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 3, 50, 40),
#               'latitude': -36.911,
#               'longitude': 142.1445,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 1, 11),
#               'latitude': -34.2536,
#               'longitude': 141.6199,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 57,
#               'date': datetime.datetime(2022, 4, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 3, 1, 7),
#               'latitude': -34.2614,
#               'longitude': 141.6412,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 15, 30, 40),
#               'latitude': -36.0933,
#               'longitude': 141.7154,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 39, 50),
#               'latitude': -36.6281,
#               'longitude': 142.4349,
#               'surface_temperature_celcius': 68}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 39, 40),
#               'latitude': -36.937,
#               'longitude': 142.1176,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 38, 10),
#               'latitude': -36.6951,
#               'longitude': 145.424,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 36, 30),
#               'latitude': -37.6714,
#               'longitude': 144.2154,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 36, 30),
#               'latitude': -38.0494,
#               'longitude': 143.9141,
#               'surface_temperature_celcius': 58}}
# {'hotspots': {'confidence': 54,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 34, 20),
#               'latitude': -38.4879,
#               'longitude': 143.9971,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#               'latitude': -37.1744,
#               'longitude': 143.9256,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 30),
#               'latitude': -36.4918,
#               'longitude': 142.2465,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#               'latitude': -36.6299,
#               'longitude': 142.4234,
#               'surface_temperature_celcius': 71}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 33, 10),
#               'latitude': -36.1439,
#               'longitude': 145.832,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 54,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 50),
#               'latitude': -36.7009,
#               'longitude': 141.541,
#               'surface_temperature_celcius': 49}}
# {'hotspots': {'confidence': 55,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'latitude': -36.4611,
#               'longitude': 143.146,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'latitude': -36.3539,
#               'longitude': 142.1894,
#               'surface_temperature_celcius': 53}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'latitude': -37.0081,
#               'longitude': 141.7654,
#               'surface_temperature_celcius': 62}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'latitude': -36.2889,
#               'longitude': 141.7692,
#               'surface_temperature_celcius': 51}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'latitude': -36.6228,
#               'longitude': 142.428,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 4, 4, 32, 40),
#               'latitude': -38.1177,
#               'longitude': 143.6409,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 13, 10, 10),
#               'latitude': -38.3499,
#               'longitude': 147.033,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 13, 2, 40),
#               'latitude': -37.6435,
#               'longitude': 146.1417,
#               'surface_temperature_celcius': 36}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 5, 15, 40),
#               'latitude': -37.7522,
#               'longitude': 142.3183,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 5, 15, 30),
#               'latitude': -36.9396,
#               'longitude': 141.9303,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 45, 10),
#               'latitude': -37.78,
#               'longitude': 141.8091,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 44, 40),
#               'latitude': -37.7767,
#               'longitude': 141.8127,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 44, 30),
#               'latitude': -38.1756,
#               'longitude': 143.9829,
#               'surface_temperature_celcius': 53}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 40, 30),
#               'latitude': -38.3553,
#               'longitude': 147.0231,
#               'surface_temperature_celcius': 38}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 40, 30),
#               'latitude': -36.934,
#               'longitude': 142.5759,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'latitude': -38.0383,
#               'longitude': 144.4307,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'latitude': -36.9354,
#               'longitude': 142.5807,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'latitude': -36.9405,
#               'longitude': 142.8627,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 5, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 5, 3, 39, 10),
#               'latitude': -37.6339,
#               'longitude': 143.4108,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 25, 40),
#               'latitude': -37.7069,
#               'longitude': 142.1573,
#               'surface_temperature_celcius': 53}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 25, 40),
#               'latitude': -36.0834,
#               'longitude': 146.5364,
#               'surface_temperature_celcius': 53}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#               'latitude': -36.3557,
#               'longitude': 141.3268,
#               'surface_temperature_celcius': 52}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#               'latitude': -37.6104,
#               'longitude': 147.8367,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#               'latitude': -37.9229,
#               'longitude': 143.647,
#               'surface_temperature_celcius': 63}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 23, 50),
#               'latitude': -37.5052,
#               'longitude': 142.8636,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 22, 20),
#               'latitude': -37.8177,
#               'longitude': 142.9168,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 21, 20),
#               'latitude': -37.5842,
#               'longitude': 148.5717,
#               'surface_temperature_celcius': 49}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#               'latitude': -38.0089,
#               'longitude': 143.8976,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 58,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 21),
#               'latitude': -37.3072,
#               'longitude': 147.5003,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 50),
#               'latitude': -37.3556,
#               'longitude': 146.1085,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -37.6806,
#               'longitude': 143.2676,
#               'surface_temperature_celcius': 51}}
# {'hotspots': {'confidence': 58,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -37.7212,
#               'longitude': 145.9754,
#               'surface_temperature_celcius': 52}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -38.3343,
#               'longitude': 143.8644,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -35.723,
#               'longitude': 142.063,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -35.1383,
#               'longitude': 141.8172,
#               'surface_temperature_celcius': 53}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -36.4133,
#               'longitude': 141.0286,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -36.6492,
#               'longitude': 142.3976,
#               'surface_temperature_celcius': 60}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -36.0765,
#               'longitude': 146.4896,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 57,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -36.0799,
#               'longitude': 146.529,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -36.8632,
#               'longitude': 142.5802,
#               'surface_temperature_celcius': 60}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -37.1929,
#               'longitude': 143.8132,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -37.1992,
#               'longitude': 146.2301,
#               'surface_temperature_celcius': 60}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -37.5914,
#               'longitude': 148.5807,
#               'surface_temperature_celcius': 61}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 4, 20, 40),
#               'latitude': -37.7496,
#               'longitude': 148.3898,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 0, 3, 50),
#               'latitude': -35.4625,
#               'longitude': 143.1486,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 4, 6, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 6, 0, 1, 40),
#               'latitude': -38.0942,
#               'longitude': 146.9603,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 12, 53, 40),
#               'latitude': -35.6961,
#               'longitude': 143.1935,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 12, 52, 10),
#               'latitude': -37.3314,
#               'longitude': 149.1283,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 12, 51, 20),
#               'latitude': -37.3359,
#               'longitude': 149.3816,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 12, 51),
#               'latitude': -37.3526,
#               'longitude': 149.3972,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 12, 50, 40),
#               'latitude': -37.3344,
#               'longitude': 149.3933,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 12, 50, 40),
#               'latitude': -37.3511,
#               'longitude': 149.4088,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 12, 50, 40),
#               'latitude': -36.7508,
#               'longitude': 147.1254,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#               'latitude': -36.1031,
#               'longitude': 143.0782,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#               'latitude': -36.1025,
#               'longitude': 143.0825,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 5, 3, 10),
#               'latitude': -36.7314,
#               'longitude': 141.8698,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 3, 31, 40),
#               'latitude': -37.7931,
#               'longitude': 148.385,
#               'surface_temperature_celcius': 58}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 7, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 7, 3, 27, 50),
#               'latitude': -37.7974,
#               'longitude': 148.5498,
#               'surface_temperature_celcius': 53}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 15, 20),
#               'latitude': -37.34,
#               'longitude': 149.3668,
#               'surface_temperature_celcius': 74}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 14, 40),
#               'latitude': -37.8567,
#               'longitude': 147.1576,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 12, 20),
#               'latitude': -37.4368,
#               'longitude': 149.1191,
#               'surface_temperature_celcius': 52}}
# {'hotspots': {'confidence': 58,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 11, 40),
#               'latitude': -37.9408,
#               'longitude': 146.0611,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 9, 20),
#               'latitude': -37.6994,
#               'longitude': 146.2162,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 8, 50),
#               'latitude': -36.7199,
#               'longitude': 142.5844,
#               'surface_temperature_celcius': 56}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 8, 40),
#               'latitude': -37.3493,
#               'longitude': 149.3691,
#               'surface_temperature_celcius': 80}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 4, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 8, 4, 8, 40),
#               'latitude': -37.6447,
#               'longitude': 148.6039,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 50, 20),
#               'latitude': -36.2282,
#               'longitude': 145.9074,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 42, 10),
#               'latitude': -36.3499,
#               'longitude': 146.1402,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 40, 30),
#               'latitude': -36.4439,
#               'longitude': 145.8846,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 57,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 39, 40),
#               'latitude': -36.0818,
#               'longitude': 146.5461,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -36.343,
#               'longitude': 143.3479,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -36.1751,
#               'longitude': 142.7831,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 55,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -36.4606,
#               'longitude': 141.0562,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 66,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -36.0156,
#               'longitude': 143.2188,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -36.1398,
#               'longitude': 141.7793,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -35.2068,
#               'longitude': 143.2912,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -36.3579,
#               'longitude': 146.1268,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 4, 38, 50),
#               'latitude': -36.0787,
#               'longitude': 146.5728,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 11, 0, 20, 30),
#               'latitude': -37.9796,
#               'longitude': 146.8024,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 13, 13, 10),
#               'latitude': -35.4309,
#               'longitude': 142.3626,
#               'surface_temperature_celcius': 36}}
# {'hotspots': {'confidence': 57,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 13, 9, 20),
#               'latitude': -35.4407,
#               'longitude': 142.3644,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 5, 28),
#               'latitude': -37.4755,
#               'longitude': 142.6339,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 54,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 5, 26, 50),
#               'latitude': -36.7453,
#               'longitude': 141.4578,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 5, 25),
#               'latitude': -36.7038,
#               'longitude': 141.0498,
#               'surface_temperature_celcius': 39}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 5, 21, 50),
#               'latitude': -37.7578,
#               'longitude': 142.227,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 5, 21, 40),
#               'latitude': -36.8083,
#               'longitude': 142.0219,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 5, 21, 40),
#               'latitude': -36.714,
#               'longitude': 141.1485,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 51),
#               'latitude': -36.6385,
#               'longitude': 142.5297,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 50, 10),
#               'latitude': -36.9179,
#               'longitude': 141.3095,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 46, 50),
#               'latitude': -37.3654,
#               'longitude': 143.8156,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 46, 20),
#               'latitude': -36.6188,
#               'longitude': 144.0402,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 46),
#               'latitude': -37.4047,
#               'longitude': 143.6615,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 46),
#               'latitude': -36.2367,
#               'longitude': 141.3998,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 45, 10),
#               'latitude': -36.5234,
#               'longitude': 144.6939,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 45),
#               'latitude': -36.6803,
#               'longitude': 141.0957,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 44, 50),
#               'latitude': -36.7866,
#               'longitude': 142.1989,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 4, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 4, 12, 3, 44, 40),
#               'latitude': -36.6292,
#               'longitude': 143.8862,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 68,
# ...
#               'latitude': -37.461,
#               'longitude': 148.109,
#               'surface_temperature_celcius': 33}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 10, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 3, 3, 58, 28),
#               'latitude': -37.236,
#               'longitude': 141.176,
#               'surface_temperature_celcius': 37}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 10, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 3, 3, 58, 28),
#               'latitude': -37.227,
#               'longitude': 141.151,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 54,
#               'date': datetime.datetime(2022, 10, 3, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 3, 1, 22, 44),
#               'latitude': -37.227,
#               'longitude': 141.146,
#               'surface_temperature_celcius': 31}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 10, 4, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 4, 4, 41, 36),
#               'latitude': -36.418,
#               'longitude': 141.596,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 16, 23, 56, 43),
#               'latitude': -37.288,
#               'longitude': 144.39,
#               'surface_temperature_celcius': 36}}
# {'hotspots': {'confidence': 58,
#               'date': datetime.datetime(2022, 10, 17, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 17, 4, 10, 38),
#               'latitude': -37.587,
#               'longitude': 142.479,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 10, 20, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 20, 0, 27, 12),
#               'latitude': -37.296,
#               'longitude': 144.386,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 10, 21, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 21, 1, 9, 54),
#               'latitude': -36.1,
#               'longitude': 143.772,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 10, 26, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 26, 4, 4, 53),
#               'latitude': -36.156,
#               'longitude': 143.568,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 10, 26, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 26, 4, 4, 53),
#               'latitude': -36.152,
#               'longitude': 143.578,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 10, 27, 0, 0),
#               'datetime': datetime.datetime(2022, 10, 27, 4, 47, 31),
#               'latitude': -36.748,
#               'longitude': 144.168,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 11, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 8, 5, 12, 8),
#               'latitude': -36.538,
#               'longitude': 141.129,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 11, 9, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 56),
#               'latitude': -36.759,
#               'longitude': 145.179,
#               'surface_temperature_celcius': 52}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 11, 9, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 56),
#               'latitude': -36.758,
#               'longitude': 145.19,
#               'surface_temperature_celcius': 51}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 11, 9, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 9, 4, 16, 46),
#               'latitude': -37.719,
#               'longitude': 142.154,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 11, 11, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 11, 15, 8),
#               'latitude': -36.943,
#               'longitude': 143.286,
#               'surface_temperature_celcius': 29}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 11, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 12, 4, 47, 32),
#               'latitude': -36.942,
#               'longitude': 143.282,
#               'surface_temperature_celcius': 53}}
# {'hotspots': {'confidence': 58,
#               'date': datetime.datetime(2022, 11, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 12, 4, 47, 16),
#               'latitude': -37.864,
#               'longitude': 144.174,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 11, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 12, 4, 46, 53),
#               'latitude': -38.912,
#               'longitude': 146.272,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 11, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 12, 0, 33, 15),
#               'latitude': -36.942,
#               'longitude': 143.292,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 13, 3, 52, 8),
#               'latitude': -37.954,
#               'longitude': 143.918,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 13, 1, 16, 38),
#               'latitude': -38.167,
#               'longitude': 143.841,
#               'surface_temperature_celcius': 38}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 13, 1, 16, 37),
#               'latitude': -38.16,
#               'longitude': 143.803,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 11, 14, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 14, 0, 21, 26),
#               'latitude': -38.527,
#               'longitude': 143.493,
#               'surface_temperature_celcius': 45}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 11, 14, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 14, 0, 21, 7),
#               'latitude': -37.332,
#               'longitude': 143.375,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 11, 23, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 23, 0, 15, 12),
#               'latitude': -38.141,
#               'longitude': 143.183,
#               'surface_temperature_celcius': 46}}
# {'hotspots': {'confidence': 63,
#               'date': datetime.datetime(2022, 11, 23, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 23, 0, 14, 47),
#               'latitude': -36.952,
#               'longitude': 144.972,
#               'surface_temperature_celcius': 60}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 11, 28, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 28, 0, 33, 14),
#               'latitude': -37.749,
#               'longitude': 148.297,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 11, 29, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#               'latitude': -37.611,
#               'longitude': 149.277,
#               'surface_temperature_celcius': 38}}
# {'hotspots': {'confidence': 68,
#               'date': datetime.datetime(2022, 11, 29, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 29, 13, 17, 24),
#               'latitude': -37.605,
#               'longitude': 149.308,
#               'surface_temperature_celcius': 43}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 11, 29, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 29, 3, 53, 16),
#               'latitude': -34.282,
#               'longitude': 142.121,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 11, 29, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 29, 3, 52, 10),
#               'latitude': -37.605,
#               'longitude': 149.326,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 52,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 23, 25, 57),
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#               'latitude': -37.58,
#               'longitude': 149.331,
#               'surface_temperature_celcius': 35}}
# {'hotspots': {'confidence': 61,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 15, 38, 32),
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 0, 21),
#               'latitude': -37.637,
#               'longitude': 146.288,
#               'surface_temperature_celcius': 42}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50}}
# {'hotspots': {'confidence': 64,
#               'date': datetime.datetime(2022, 11, 30, 0, 0),
#               'datetime': datetime.datetime(2022, 11, 30, 0, 20, 49),
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41}}
# {'hotspots': {'confidence': 56,
#               'date': datetime.datetime(2022, 12, 8, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 8, 13, 11, 43),
#               'latitude': -36.291,
#               'longitude': 146.159,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 50,
#               'date': datetime.datetime(2022, 12, 10, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 10, 0, 57, 59),
#               'latitude': -37.987,
#               'longitude': 144.005,
#               'surface_temperature_celcius': 38}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 12, 10, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 10, 0, 56, 57),
#               'latitude': -34.289,
#               'longitude': 141.712,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 12, 12, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 12, 0, 45, 38),
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44}}
# {'hotspots': {'confidence': 51,
#               'date': datetime.datetime(2022, 12, 15, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 15, 13, 17, 17),
#               'latitude': -37.623,
#               'longitude': 149.323,
#               'surface_temperature_celcius': 38}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 12, 15, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 15, 1, 16, 23),
#               'latitude': -38.038,
#               'longitude': 142.986,
#               'surface_temperature_celcius': 40}}
# {'hotspots': {'confidence': 69,
#               'date': datetime.datetime(2022, 12, 16, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 16, 15, 38, 39),
#               'latitude': -37.624,
#               'longitude': 149.332,
#               'surface_temperature_celcius': 33}}
# {'hotspots': {'confidence': 62,
#               'date': datetime.datetime(2022, 12, 16, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 16, 4, 35, 15),
#               'latitude': -37.82,
#               'longitude': 142.323,
#               'surface_temperature_celcius': 54}}
# {'hotspots': {'confidence': 59,
#               'date': datetime.datetime(2022, 12, 16, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 16, 4, 34, 57),
#               'latitude': -37.644,
#               'longitude': 149.346,
#               'surface_temperature_celcius': 55}}
# {'hotspots': {'confidence': 60,
#               'date': datetime.datetime(2022, 12, 16, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 16, 0, 21, 11),
#               'latitude': -38.046,
#               'longitude': 144.201,
#               'surface_temperature_celcius': 48}}
# {'hotspots': {'confidence': 53,
#               'date': datetime.datetime(2022, 12, 16, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 16, 0, 20, 53),
#               'latitude': -37.63,
#               'longitude': 149.335,
#               'surface_temperature_celcius': 57}}
# {'hotspots': {'confidence': 65,
#               'date': datetime.datetime(2022, 12, 24, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 24, 13, 12, 1),
#               'latitude': -35.646,
#               'longitude': 142.282,
#               'surface_temperature_celcius': 32}}
# {'hotspots': {'confidence': 67,
#               'date': datetime.datetime(2022, 12, 27, 0, 0),
#               'datetime': datetime.datetime(2022, 12, 27, 0, 2, 15),
#               'latitude': -35.554,
#               'longitude': 143.307,
#               'surface_temperature_celcius': 53}}

# %% [markdown]
# *h. Find the average surface temperature (°C) for each day. You are required to only display average surface temperature (°C) and the date in the output.*

# %%
result = collection.aggregate([
    # ensure climate data with empty hotspot will be included after unwind
    {'$unwind': {
        'path': '$hotspots',
        'preserveNullAndEmptyArrays': True
    }},
    # compute average surface temperature for each day
    {'$group': {'_id': '$date', 'avg': {'$avg': '$hotspots.surface_temperature_celcius'}}},
    # rename fields
    {'$project': {'date': '$_id', 'avg_surface_temperature': '$avg', '_id': 0}},
    # sort by increasing date 
    {'$sort': {'date': 1}}
])

for document in result:
    # format date to be more readable 
    document['date'] = document['date'].strftime('%d-%m-%Y')
    pprint(document)
# Out:
# {'avg_surface_temperature': None, 'date': '31-12-2021'}
# {'avg_surface_temperature': None, 'date': '02-01-2022'}
# {'avg_surface_temperature': None, 'date': '03-01-2022'}
# {'avg_surface_temperature': None, 'date': '04-01-2022'}
# {'avg_surface_temperature': None, 'date': '05-01-2022'}
# {'avg_surface_temperature': None, 'date': '06-01-2022'}
# {'avg_surface_temperature': None, 'date': '07-01-2022'}
# {'avg_surface_temperature': None, 'date': '08-01-2022'}
# {'avg_surface_temperature': None, 'date': '09-01-2022'}
# {'avg_surface_temperature': None, 'date': '10-01-2022'}
# {'avg_surface_temperature': None, 'date': '11-01-2022'}
# {'avg_surface_temperature': None, 'date': '12-01-2022'}
# {'avg_surface_temperature': None, 'date': '13-01-2022'}
# {'avg_surface_temperature': None, 'date': '14-01-2022'}
# {'avg_surface_temperature': None, 'date': '15-01-2022'}
# {'avg_surface_temperature': None, 'date': '16-01-2022'}
# {'avg_surface_temperature': None, 'date': '17-01-2022'}
# {'avg_surface_temperature': None, 'date': '18-01-2022'}
# {'avg_surface_temperature': None, 'date': '19-01-2022'}
# {'avg_surface_temperature': None, 'date': '20-01-2022'}
# {'avg_surface_temperature': None, 'date': '21-01-2022'}
# {'avg_surface_temperature': None, 'date': '22-01-2022'}
# {'avg_surface_temperature': None, 'date': '23-01-2022'}
# {'avg_surface_temperature': None, 'date': '24-01-2022'}
# {'avg_surface_temperature': None, 'date': '25-01-2022'}
# {'avg_surface_temperature': None, 'date': '26-01-2022'}
# {'avg_surface_temperature': None, 'date': '27-01-2022'}
# {'avg_surface_temperature': None, 'date': '28-01-2022'}
# {'avg_surface_temperature': None, 'date': '29-01-2022'}
# {'avg_surface_temperature': None, 'date': '30-01-2022'}
# {'avg_surface_temperature': None, 'date': '31-01-2022'}
# {'avg_surface_temperature': None, 'date': '01-02-2022'}
# {'avg_surface_temperature': None, 'date': '02-02-2022'}
# {'avg_surface_temperature': None, 'date': '03-02-2022'}
# {'avg_surface_temperature': None, 'date': '04-02-2022'}
# {'avg_surface_temperature': None, 'date': '05-02-2022'}
# {'avg_surface_temperature': None, 'date': '06-02-2022'}
# {'avg_surface_temperature': None, 'date': '07-02-2022'}
# {'avg_surface_temperature': None, 'date': '08-02-2022'}
# {'avg_surface_temperature': None, 'date': '09-02-2022'}
# {'avg_surface_temperature': None, 'date': '10-02-2022'}
# {'avg_surface_temperature': None, 'date': '11-02-2022'}
# {'avg_surface_temperature': None, 'date': '12-02-2022'}
# {'avg_surface_temperature': None, 'date': '13-02-2022'}
# {'avg_surface_temperature': None, 'date': '14-02-2022'}
# {'avg_surface_temperature': None, 'date': '15-02-2022'}
# {'avg_surface_temperature': None, 'date': '16-02-2022'}
# {'avg_surface_temperature': None, 'date': '17-02-2022'}
# {'avg_surface_temperature': None, 'date': '18-02-2022'}
# {'avg_surface_temperature': None, 'date': '19-02-2022'}
# {'avg_surface_temperature': None, 'date': '20-02-2022'}
# {'avg_surface_temperature': None, 'date': '21-02-2022'}
# {'avg_surface_temperature': None, 'date': '22-02-2022'}
# {'avg_surface_temperature': None, 'date': '23-02-2022'}
# {'avg_surface_temperature': None, 'date': '24-02-2022'}
# {'avg_surface_temperature': None, 'date': '25-02-2022'}
# {'avg_surface_temperature': None, 'date': '26-02-2022'}
# {'avg_surface_temperature': None, 'date': '27-02-2022'}
# {'avg_surface_temperature': None, 'date': '28-02-2022'}
# {'avg_surface_temperature': None, 'date': '01-03-2022'}
# {'avg_surface_temperature': None, 'date': '02-03-2022'}
# {'avg_surface_temperature': None, 'date': '03-03-2022'}
# {'avg_surface_temperature': None, 'date': '04-03-2022'}
# {'avg_surface_temperature': None, 'date': '05-03-2022'}
# {'avg_surface_temperature': 60.5, 'date': '06-03-2022'}
# {'avg_surface_temperature': 64.0, 'date': '07-03-2022'}
# {'avg_surface_temperature': 51.5, 'date': '08-03-2022'}
# {'avg_surface_temperature': 46.666666666666664, 'date': '09-03-2022'}
# {'avg_surface_temperature': 69.375, 'date': '10-03-2022'}
# {'avg_surface_temperature': None, 'date': '11-03-2022'}
# {'avg_surface_temperature': 88.2, 'date': '12-03-2022'}
# {'avg_surface_temperature': 38.5, 'date': '13-03-2022'}
# {'avg_surface_temperature': 65.6, 'date': '14-03-2022'}
# {'avg_surface_temperature': 46.0, 'date': '15-03-2022'}
# {'avg_surface_temperature': None, 'date': '16-03-2022'}
# {'avg_surface_temperature': 59.5, 'date': '17-03-2022'}
# {'avg_surface_temperature': 79.33333333333333, 'date': '18-03-2022'}
# {'avg_surface_temperature': 65.57142857142857, 'date': '19-03-2022'}
# {'avg_surface_temperature': None, 'date': '20-03-2022'}
# {'avg_surface_temperature': None, 'date': '21-03-2022'}
# {'avg_surface_temperature': None, 'date': '22-03-2022'}
# {'avg_surface_temperature': None, 'date': '23-03-2022'}
# {'avg_surface_temperature': 49.0, 'date': '24-03-2022'}
# {'avg_surface_temperature': 66.0, 'date': '25-03-2022'}
# {'avg_surface_temperature': 56.88235294117647, 'date': '26-03-2022'}
# {'avg_surface_temperature': None, 'date': '27-03-2022'}
# {'avg_surface_temperature': 60.925925925925924, 'date': '28-03-2022'}
# {'avg_surface_temperature': 51.0, 'date': '29-03-2022'}
# {'avg_surface_temperature': None, 'date': '30-03-2022'}
# {'avg_surface_temperature': 48.72727272727273, 'date': '31-03-2022'}
# {'avg_surface_temperature': 46.714285714285715, 'date': '01-04-2022'}
# {'avg_surface_temperature': 45.2, 'date': '02-04-2022'}
# {'avg_surface_temperature': 58.44444444444444, 'date': '03-04-2022'}
# {'avg_surface_temperature': 62.57303370786517, 'date': '04-04-2022'}
# {'avg_surface_temperature': 53.142857142857146, 'date': '05-04-2022'}
# {'avg_surface_temperature': 61.71186440677966, 'date': '06-04-2022'}
# {'avg_surface_temperature': 50.69230769230769, 'date': '07-04-2022'}
# {'avg_surface_temperature': 60.75, 'date': '08-04-2022'}
# {'avg_surface_temperature': None, 'date': '09-04-2022'}
# {'avg_surface_temperature': None, 'date': '10-04-2022'}
# {'avg_surface_temperature': 46.291666666666664, 'date': '11-04-2022'}
# {'avg_surface_temperature': 52.69565217391305, 'date': '12-04-2022'}
# {'avg_surface_temperature': 58.57983193277311, 'date': '13-04-2022'}
# {'avg_surface_temperature': 61.94444444444444, 'date': '14-04-2022'}
# {'avg_surface_temperature': 59.57971014492754, 'date': '15-04-2022'}
# {'avg_surface_temperature': 48.72222222222222, 'date': '16-04-2022'}
# {'avg_surface_temperature': 50.921052631578945, 'date': '17-04-2022'}
# {'avg_surface_temperature': 53.36615384615384, 'date': '18-04-2022'}
# {'avg_surface_temperature': 54.16, 'date': '19-04-2022'}
# {'avg_surface_temperature': 56.58064516129032, 'date': '20-04-2022'}
# {'avg_surface_temperature': None, 'date': '21-04-2022'}
# {'avg_surface_temperature': 54.5, 'date': '22-04-2022'}
# {'avg_surface_temperature': 53.89473684210526, 'date': '23-04-2022'}
# {'avg_surface_temperature': 59.375, 'date': '24-04-2022'}
# {'avg_surface_temperature': 48.666666666666664, 'date': '25-04-2022'}
# {'avg_surface_temperature': 34.0, 'date': '26-04-2022'}
# {'avg_surface_temperature': None, 'date': '27-04-2022'}
# {'avg_surface_temperature': None, 'date': '28-04-2022'}
# {'avg_surface_temperature': 63.0, 'date': '29-04-2022'}
# {'avg_surface_temperature': None, 'date': '30-04-2022'}
# {'avg_surface_temperature': 68.4, 'date': '01-05-2022'}
# {'avg_surface_temperature': 55.6, 'date': '02-05-2022'}
# {'avg_surface_temperature': 56.796875, 'date': '03-05-2022'}
# {'avg_surface_temperature': 56.80740740740741, 'date': '04-05-2022'}
# {'avg_surface_temperature': 51.70967741935484, 'date': '05-05-2022'}
# {'avg_surface_temperature': 57.529411764705884, 'date': '06-05-2022'}
# {'avg_surface_temperature': 50.333333333333336, 'date': '07-05-2022'}
# {'avg_surface_temperature': 56.291666666666664, 'date': '08-05-2022'}
# {'avg_surface_temperature': 42.46153846153846, 'date': '09-05-2022'}
# {'avg_surface_temperature': 52.86842105263158, 'date': '10-05-2022'}
# {'avg_surface_temperature': 59.36842105263158, 'date': '11-05-2022'}
# {'avg_surface_temperature': 51.5, 'date': '12-05-2022'}
# {'avg_surface_temperature': 58.611111111111114, 'date': '13-05-2022'}
# {'avg_surface_temperature': 49.0, 'date': '14-05-2022'}
# {'avg_surface_temperature': 53.950980392156865, 'date': '15-05-2022'}
# {'avg_surface_temperature': 39.666666666666664, 'date': '16-05-2022'}
# {'avg_surface_temperature': 52.0, 'date': '17-05-2022'}
# {'avg_surface_temperature': 44.142857142857146, 'date': '18-05-2022'}
# {'avg_surface_temperature': None, 'date': '19-05-2022'}
# {'avg_surface_temperature': None, 'date': '20-05-2022'}
# {'avg_surface_temperature': None, 'date': '21-05-2022'}
# {'avg_surface_temperature': 54.484848484848484, 'date': '22-05-2022'}
# {'avg_surface_temperature': 51.2, 'date': '23-05-2022'}
# {'avg_surface_temperature': 40.333333333333336, 'date': '24-05-2022'}
# {'avg_surface_temperature': None, 'date': '25-05-2022'}
# {'avg_surface_temperature': 49.5, 'date': '26-05-2022'}
# {'avg_surface_temperature': None, 'date': '27-05-2022'}
# {'avg_surface_temperature': None, 'date': '28-05-2022'}
# {'avg_surface_temperature': None, 'date': '29-05-2022'}
# {'avg_surface_temperature': None, 'date': '30-05-2022'}
# {'avg_surface_temperature': None, 'date': '31-05-2022'}
# {'avg_surface_temperature': 54.0, 'date': '01-06-2022'}
# {'avg_surface_temperature': 47.72727272727273, 'date': '02-06-2022'}
# {'avg_surface_temperature': 47.0, 'date': '03-06-2022'}
# {'avg_surface_temperature': 52.22222222222222, 'date': '04-06-2022'}
# {'avg_surface_temperature': None, 'date': '05-06-2022'}
# {'avg_surface_temperature': None, 'date': '06-06-2022'}
# {'avg_surface_temperature': 51.857142857142854, 'date': '07-06-2022'}
# {'avg_surface_temperature': None, 'date': '08-06-2022'}
# {'avg_surface_temperature': 49.0, 'date': '09-06-2022'}
# {'avg_surface_temperature': None, 'date': '10-06-2022'}
# {'avg_surface_temperature': 41.5, 'date': '11-06-2022'}
# {'avg_surface_temperature': None, 'date': '12-06-2022'}
# {'avg_surface_temperature': 41.0, 'date': '13-06-2022'}
# {'avg_surface_temperature': 53.25, 'date': '14-06-2022'}
# {'avg_surface_temperature': None, 'date': '15-06-2022'}
# {'avg_surface_temperature': 42.5, 'date': '16-06-2022'}
# {'avg_surface_temperature': None, 'date': '17-06-2022'}
# {'avg_surface_temperature': 42.0, 'date': '18-06-2022'}
# {'avg_surface_temperature': None, 'date': '19-06-2022'}
# {'avg_surface_temperature': 71.16666666666667, 'date': '20-06-2022'}
# {'avg_surface_temperature': None, 'date': '21-06-2022'}
# {'avg_surface_temperature': 46.0, 'date': '22-06-2022'}
# {'avg_surface_temperature': None, 'date': '23-06-2022'}
# {'avg_surface_temperature': None, 'date': '24-06-2022'}
# {'avg_surface_temperature': None, 'date': '25-06-2022'}
# {'avg_surface_temperature': None, 'date': '26-06-2022'}
# {'avg_surface_temperature': None, 'date': '27-06-2022'}
# {'avg_surface_temperature': None, 'date': '28-06-2022'}
# {'avg_surface_temperature': None, 'date': '29-06-2022'}
# {'avg_surface_temperature': 44.333333333333336, 'date': '30-06-2022'}
# {'avg_surface_temperature': 30.5, 'date': '01-07-2022'}
# {'avg_surface_temperature': 43.5, 'date': '02-07-2022'}
# {'avg_surface_temperature': None, 'date': '03-07-2022'}
# {'avg_surface_temperature': 40.0, 'date': '04-07-2022'}
# {'avg_surface_temperature': 45.0, 'date': '05-07-2022'}
# {'avg_surface_temperature': 56.0, 'date': '06-07-2022'}
# {'avg_surface_temperature': None, 'date': '07-07-2022'}
# {'avg_surface_temperature': None, 'date': '08-07-2022'}
# {'avg_surface_temperature': None, 'date': '09-07-2022'}
# {'avg_surface_temperature': None, 'date': '10-07-2022'}
# {'avg_surface_temperature': None, 'date': '11-07-2022'}
# {'avg_surface_temperature': None, 'date': '12-07-2022'}
# {'avg_surface_temperature': None, 'date': '13-07-2022'}
# {'avg_surface_temperature': 41.5, 'date': '14-07-2022'}
# {'avg_surface_temperature': None, 'date': '15-07-2022'}
# {'avg_surface_temperature': None, 'date': '16-07-2022'}
# {'avg_surface_temperature': None, 'date': '17-07-2022'}
# {'avg_surface_temperature': None, 'date': '18-07-2022'}
# {'avg_surface_temperature': None, 'date': '19-07-2022'}
# {'avg_surface_temperature': None, 'date': '20-07-2022'}
# {'avg_surface_temperature': None, 'date': '21-07-2022'}
# {'avg_surface_temperature': None, 'date': '22-07-2022'}
# {'avg_surface_temperature': None, 'date': '23-07-2022'}
# {'avg_surface_temperature': None, 'date': '24-07-2022'}
# {'avg_surface_temperature': None, 'date': '25-07-2022'}
# {'avg_surface_temperature': None, 'date': '26-07-2022'}
# {'avg_surface_temperature': None, 'date': '27-07-2022'}
# {'avg_surface_temperature': None, 'date': '28-07-2022'}
# {'avg_surface_temperature': 48.0, 'date': '29-07-2022'}
# {'avg_surface_temperature': None, 'date': '30-07-2022'}
# {'avg_surface_temperature': 47.0, 'date': '31-07-2022'}
# {'avg_surface_temperature': 58.0, 'date': '01-08-2022'}
# {'avg_surface_temperature': 63.5, 'date': '02-08-2022'}
# {'avg_surface_temperature': None, 'date': '03-08-2022'}
# {'avg_surface_temperature': None, 'date': '04-08-2022'}
# {'avg_surface_temperature': 40.0, 'date': '05-08-2022'}
# {'avg_surface_temperature': None, 'date': '06-08-2022'}
# {'avg_surface_temperature': None, 'date': '07-08-2022'}
# {'avg_surface_temperature': None, 'date': '08-08-2022'}
# {'avg_surface_temperature': None, 'date': '09-08-2022'}
# {'avg_surface_temperature': 63.0, 'date': '10-08-2022'}
# {'avg_surface_temperature': None, 'date': '11-08-2022'}
# {'avg_surface_temperature': None, 'date': '12-08-2022'}
# {'avg_surface_temperature': 49.0, 'date': '13-08-2022'}
# {'avg_surface_temperature': 40.8, 'date': '14-08-2022'}
# {'avg_surface_temperature': None, 'date': '15-08-2022'}
# {'avg_surface_temperature': None, 'date': '16-08-2022'}
# {'avg_surface_temperature': None, 'date': '17-08-2022'}
# {'avg_surface_temperature': None, 'date': '18-08-2022'}
# {'avg_surface_temperature': None, 'date': '19-08-2022'}
# {'avg_surface_temperature': None, 'date': '20-08-2022'}
# {'avg_surface_temperature': None, 'date': '21-08-2022'}
# {'avg_surface_temperature': None, 'date': '22-08-2022'}
# {'avg_surface_temperature': None, 'date': '23-08-2022'}
# {'avg_surface_temperature': None, 'date': '24-08-2022'}
# {'avg_surface_temperature': None, 'date': '25-08-2022'}
# {'avg_surface_temperature': None, 'date': '26-08-2022'}
# {'avg_surface_temperature': None, 'date': '27-08-2022'}
# {'avg_surface_temperature': None, 'date': '28-08-2022'}
# {'avg_surface_temperature': None, 'date': '29-08-2022'}
# {'avg_surface_temperature': None, 'date': '30-08-2022'}
# {'avg_surface_temperature': None, 'date': '31-08-2022'}
# {'avg_surface_temperature': None, 'date': '01-09-2022'}
# {'avg_surface_temperature': None, 'date': '02-09-2022'}
# {'avg_surface_temperature': None, 'date': '03-09-2022'}
# {'avg_surface_temperature': None, 'date': '04-09-2022'}
# {'avg_surface_temperature': None, 'date': '05-09-2022'}
# {'avg_surface_temperature': None, 'date': '06-09-2022'}
# {'avg_surface_temperature': None, 'date': '07-09-2022'}
# {'avg_surface_temperature': None, 'date': '08-09-2022'}
# {'avg_surface_temperature': None, 'date': '09-09-2022'}
# {'avg_surface_temperature': 56.5, 'date': '10-09-2022'}
# {'avg_surface_temperature': None, 'date': '11-09-2022'}
# {'avg_surface_temperature': None, 'date': '12-09-2022'}
# {'avg_surface_temperature': None, 'date': '13-09-2022'}
# {'avg_surface_temperature': None, 'date': '14-09-2022'}
# {'avg_surface_temperature': None, 'date': '15-09-2022'}
# {'avg_surface_temperature': None, 'date': '16-09-2022'}
# {'avg_surface_temperature': None, 'date': '17-09-2022'}
# {'avg_surface_temperature': None, 'date': '18-09-2022'}
# {'avg_surface_temperature': None, 'date': '19-09-2022'}
# {'avg_surface_temperature': 63.6, 'date': '20-09-2022'}
# {'avg_surface_temperature': 40.5, 'date': '21-09-2022'}
# {'avg_surface_temperature': 45.0, 'date': '22-09-2022'}
# {'avg_surface_temperature': 52.73913043478261, 'date': '23-09-2022'}
# {'avg_surface_temperature': 53.57142857142857, 'date': '24-09-2022'}
# {'avg_surface_temperature': None, 'date': '25-09-2022'}
# {'avg_surface_temperature': 33.0, 'date': '26-09-2022'}
# {'avg_surface_temperature': 49.714285714285715, 'date': '27-09-2022'}
# {'avg_surface_temperature': None, 'date': '28-09-2022'}
# {'avg_surface_temperature': 43.0, 'date': '29-09-2022'}
# {'avg_surface_temperature': None, 'date': '30-09-2022'}
# {'avg_surface_temperature': 48.25, 'date': '01-10-2022'}
# {'avg_surface_temperature': 43.57142857142857, 'date': '02-10-2022'}
# {'avg_surface_temperature': 50.0, 'date': '03-10-2022'}
# {'avg_surface_temperature': 49.0, 'date': '04-10-2022'}
# {'avg_surface_temperature': None, 'date': '05-10-2022'}
# {'avg_surface_temperature': 44.0, 'date': '06-10-2022'}
# {'avg_surface_temperature': 42.0, 'date': '07-10-2022'}
# {'avg_surface_temperature': 41.0, 'date': '08-10-2022'}
# {'avg_surface_temperature': 44.0, 'date': '09-10-2022'}
# {'avg_surface_temperature': 53.333333333333336, 'date': '10-10-2022'}
# {'avg_surface_temperature': None, 'date': '11-10-2022'}
# {'avg_surface_temperature': None, 'date': '12-10-2022'}
# {'avg_surface_temperature': None, 'date': '13-10-2022'}
# {'avg_surface_temperature': None, 'date': '14-10-2022'}
# {'avg_surface_temperature': 72.66666666666667, 'date': '15-10-2022'}
# {'avg_surface_temperature': 36.0, 'date': '16-10-2022'}
# {'avg_surface_temperature': 51.6, 'date': '17-10-2022'}
# {'avg_surface_temperature': 52.166666666666664, 'date': '18-10-2022'}
# {'avg_surface_temperature': None, 'date': '19-10-2022'}
# {'avg_surface_temperature': 50.0, 'date': '20-10-2022'}
# {'avg_surface_temperature': 51.25, 'date': '21-10-2022'}
# {'avg_surface_temperature': None, 'date': '22-10-2022'}
# {'avg_surface_temperature': 38.0, 'date': '23-10-2022'}
# {'avg_surface_temperature': None, 'date': '24-10-2022'}
# {'avg_surface_temperature': None, 'date': '25-10-2022'}
# {'avg_surface_temperature': 44.6, 'date': '26-10-2022'}
# {'avg_surface_temperature': 50.4, 'date': '27-10-2022'}
# {'avg_surface_temperature': 56.0, 'date': '28-10-2022'}
# {'avg_surface_temperature': None, 'date': '29-10-2022'}
# {'avg_surface_temperature': None, 'date': '30-10-2022'}
# {'avg_surface_temperature': None, 'date': '31-10-2022'}
# {'avg_surface_temperature': None, 'date': '01-11-2022'}
# {'avg_surface_temperature': None, 'date': '02-11-2022'}
# {'avg_surface_temperature': None, 'date': '03-11-2022'}
# {'avg_surface_temperature': None, 'date': '04-11-2022'}
# {'avg_surface_temperature': 58.5, 'date': '05-11-2022'}
# {'avg_surface_temperature': None, 'date': '06-11-2022'}
# {'avg_surface_temperature': None, 'date': '07-11-2022'}
# {'avg_surface_temperature': 45.5, 'date': '08-11-2022'}
# {'avg_surface_temperature': 61.3, 'date': '09-11-2022'}
# {'avg_surface_temperature': None, 'date': '10-11-2022'}
# {'avg_surface_temperature': 46.25, 'date': '11-11-2022'}
# {'avg_surface_temperature': 53.0, 'date': '12-11-2022'}
# {'avg_surface_temperature': 47.0, 'date': '13-11-2022'}
# {'avg_surface_temperature': 52.0, 'date': '14-11-2022'}
# {'avg_surface_temperature': None, 'date': '15-11-2022'}
# {'avg_surface_temperature': None, 'date': '16-11-2022'}
# {'avg_surface_temperature': None, 'date': '17-11-2022'}
# {'avg_surface_temperature': None, 'date': '18-11-2022'}
# {'avg_surface_temperature': None, 'date': '19-11-2022'}
# {'avg_surface_temperature': None, 'date': '20-11-2022'}
# {'avg_surface_temperature': 59.0, 'date': '21-11-2022'}
# {'avg_surface_temperature': 61.5, 'date': '22-11-2022'}
# {'avg_surface_temperature': 58.8, 'date': '23-11-2022'}
# {'avg_surface_temperature': None, 'date': '24-11-2022'}
# {'avg_surface_temperature': None, 'date': '25-11-2022'}
# {'avg_surface_temperature': None, 'date': '26-11-2022'}
# {'avg_surface_temperature': None, 'date': '27-11-2022'}
# {'avg_surface_temperature': 42.0, 'date': '28-11-2022'}
# {'avg_surface_temperature': 60.625, 'date': '29-11-2022'}
# {'avg_surface_temperature': 52.41935483870968, 'date': '30-11-2022'}
# {'avg_surface_temperature': None, 'date': '01-12-2022'}
# {'avg_surface_temperature': None, 'date': '02-12-2022'}
# {'avg_surface_temperature': None, 'date': '03-12-2022'}
# {'avg_surface_temperature': None, 'date': '04-12-2022'}
# {'avg_surface_temperature': None, 'date': '05-12-2022'}
# {'avg_surface_temperature': None, 'date': '06-12-2022'}
# {'avg_surface_temperature': None, 'date': '07-12-2022'}
# {'avg_surface_temperature': 50.6, 'date': '08-12-2022'}
# {'avg_surface_temperature': 58.25, 'date': '09-12-2022'}
# {'avg_surface_temperature': 46.0, 'date': '10-12-2022'}
# {'avg_surface_temperature': None, 'date': '11-12-2022'}
# {'avg_surface_temperature': 44.0, 'date': '12-12-2022'}
# {'avg_surface_temperature': 60.0, 'date': '13-12-2022'}
# {'avg_surface_temperature': 70.0, 'date': '14-12-2022'}
# {'avg_surface_temperature': 39.0, 'date': '15-12-2022'}
# {'avg_surface_temperature': 57.8, 'date': '16-12-2022'}
# {'avg_surface_temperature': None, 'date': '17-12-2022'}
# {'avg_surface_temperature': None, 'date': '18-12-2022'}
# {'avg_surface_temperature': None, 'date': '19-12-2022'}
# {'avg_surface_temperature': None, 'date': '20-12-2022'}
# {'avg_surface_temperature': 46.0, 'date': '21-12-2022'}
# {'avg_surface_temperature': None, 'date': '22-12-2022'}
# {'avg_surface_temperature': None, 'date': '23-12-2022'}
# {'avg_surface_temperature': 32.0, 'date': '24-12-2022'}
# {'avg_surface_temperature': 54.0, 'date': '25-12-2022'}
# {'avg_surface_temperature': None, 'date': '26-12-2022'}
# {'avg_surface_temperature': 62.75, 'date': '27-12-2022'}
# {'avg_surface_temperature': None, 'date': '28-12-2022'}
# {'avg_surface_temperature': None, 'date': '29-12-2022'}
# {'avg_surface_temperature': None, 'date': '30-12-2022'}
# {'avg_surface_temperature': None, 'date': '31-12-2022'}
# {'avg_surface_temperature': None, 'date': '01-01-2023'}

# %% [markdown]
# *i.	Find the top 10 records with the lowest GHI.*

# %%
# sort by GHI in ascending order 
# retrieve top 10 records only
result = collection.find().sort('GHI_w/m2', 1).limit(10)

for document in result:
    pprint(document)
# Out:
# {'GHI_w/m2': 47,
#  '_id': ObjectId('6481357e25c02be8d1a09882'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2022, 8, 2, 0, 0),
#  'hotspots': [{'confidence': 94,
#                'date': datetime.datetime(2022, 8, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 8, 2, 3, 45, 40),
#                'latitude': -37.4796,
#                'longitude': 141.9403,
#                'surface_temperature_celcius': 87},
#               {'confidence': 54,
#                'date': datetime.datetime(2022, 8, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 8, 2, 3, 45),
#                'latitude': -37.491,
#                'longitude': 141.936,
#                'surface_temperature_celcius': 40}],
#  'max_wind_speed': 5.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 48,
#  '_id': ObjectId('6481357e25c02be8d1a09861'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2022, 6, 30, 0, 0),
#  'hotspots': [{'confidence': 78,
#                'date': datetime.datetime(2022, 6, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 6, 30, 4, 41, 25),
#                'latitude': -36.834,
#                'longitude': 142.524,
#                'surface_temperature_celcius': 44},
#               {'confidence': 78,
#                'date': datetime.datetime(2022, 6, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 6, 30, 4, 41, 25),
#                'latitude': -36.834,
#                'longitude': 142.524,
#                'surface_temperature_celcius': 44},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 6, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 6, 30, 0, 27, 19),
#                'latitude': -37.858,
#                'longitude': 143.428,
#                'surface_temperature_celcius': 48},
#               {'confidence': 75,
#                'date': datetime.datetime(2022, 6, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 6, 30, 0, 27, 19),
#                'latitude': -37.856,
#                'longitude': 143.416,
#                'surface_temperature_celcius': 41},
#               {'confidence': 75,
#                'date': datetime.datetime(2022, 6, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 6, 30, 0, 27, 19),
#                'latitude': -37.856,
#                'longitude': 143.416,
#                'surface_temperature_celcius': 41},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 6, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 6, 30, 0, 27, 19),
#                'latitude': -37.858,
#                'longitude': 143.428,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  '_id': ObjectId('6481357e25c02be8d1a09862'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2022, 7, 1, 0, 0),
#  'hotspots': [{'confidence': 53,
#                'date': datetime.datetime(2022, 7, 1, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 1, 13, 11, 41),
#                'latitude': -37.062,
#                'longitude': 141.373,
#                'surface_temperature_celcius': 29},
#               {'confidence': 53,
#                'date': datetime.datetime(2022, 7, 1, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 1, 13, 11, 41),
#                'latitude': -37.062,
#                'longitude': 141.373,
#                'surface_temperature_celcius': 29},
#               {'confidence': 61,
#                'date': datetime.datetime(2022, 7, 1, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 1, 3, 46, 8),
#                'latitude': -36.779,
#                'longitude': 146.108,
#                'surface_temperature_celcius': 32},
#               {'confidence': 61,
#                'date': datetime.datetime(2022, 7, 1, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 1, 3, 46, 8),
#                'latitude': -36.779,
#                'longitude': 146.108,
#                'surface_temperature_celcius': 32}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 56,
#  '_id': ObjectId('6481357e25c02be8d1a0986c'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2022, 7, 11, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 5.1,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 57,
#  '_id': ObjectId('6481357e25c02be8d1a09870'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2022, 7, 15, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  '_id': ObjectId('6481357e25c02be8d1a09863'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2022, 7, 2, 0, 0),
#  'hotspots': [{'confidence': 84,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 29, 18),
#                'latitude': -36.397,
#                'longitude': 142.254,
#                'surface_temperature_celcius': 52},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 29, 18),
#                'latitude': -36.397,
#                'longitude': 142.254,
#                'surface_temperature_celcius': 52},
#               {'confidence': 69,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 29, 10),
#                'latitude': -37.067,
#                'longitude': 141.379,
#                'surface_temperature_celcius': 36},
#               {'confidence': 69,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 29, 10),
#                'latitude': -37.067,
#                'longitude': 141.379,
#                'surface_temperature_celcius': 36},
#               {'confidence': 88,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 29),
#                'latitude': -37.333,
#                'longitude': 143.534,
#                'surface_temperature_celcius': 58},
#               {'confidence': 88,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 29),
#                'latitude': -37.333,
#                'longitude': 143.534,
#                'surface_temperature_celcius': 58},
#               {'confidence': 50,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 28, 42),
#                'latitude': -37.886,
#                'longitude': 147.207,
#                'surface_temperature_celcius': 28},
#               {'confidence': 50,
#                'date': datetime.datetime(2022, 7, 2, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 2, 4, 28, 42),
#                'latitude': -37.886,
#                'longitude': 147.207,
#                'surface_temperature_celcius': 28}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('6481357e25c02be8d1a09881'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2022, 8, 1, 0, 0),
#  'hotspots': [{'confidence': 89,
#                'date': datetime.datetime(2022, 8, 1, 0, 0),
#                'datetime': datetime.datetime(2022, 8, 1, 0, 20, 30),
#                'latitude': -38.3998,
#                'longitude': 147.064,
#                'surface_temperature_celcius': 65},
#               {'confidence': 78,
#                'date': datetime.datetime(2022, 8, 1, 0, 0),
#                'datetime': datetime.datetime(2022, 8, 1, 0, 19, 30),
#                'latitude': -38.3982,
#                'longitude': 147.0509,
#                'surface_temperature_celcius': 51}],
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('6481357e25c02be8d1a09875'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2022, 7, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('6481357e25c02be8d1a09880'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2022, 7, 31, 0, 0),
#  'hotspots': [{'confidence': 100,
#                'date': datetime.datetime(2022, 7, 31, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 31, 13, 21),
#                'latitude': -37.8641,
#                'longitude': 143.4276,
#                'surface_temperature_celcius': 51},
#               {'confidence': 92,
#                'date': datetime.datetime(2022, 7, 31, 0, 0),
#                'datetime': datetime.datetime(2022, 7, 31, 13, 21),
#                'latitude': -37.8658,
#                'longitude': 143.4162,
#                'surface_temperature_celcius': 43}],
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'GHI_w/m2': 66,
#  '_id': ObjectId('6481357e25c02be8d1a09893'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2022, 8, 19, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %% [markdown]
# *j.	Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.*

# %%
# 24 hour precipitation = D F G (flag)
result = collection.find({
    'precipitation_flag': {'$in': ['D', 'F', 'G']},
    'precipitation': {'$gte': 0.20, '$lte': 0.35}
})

for document in result:
    pprint(document)
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('6481357e25c02be8d1a097b9'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 1, 13, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('6481357e25c02be8d1a09804'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 3, 29, 0, 0),
#  'hotspots': [{'confidence': 69,
#                'date': datetime.datetime(2022, 3, 29, 0, 0),
#                'datetime': datetime.datetime(2022, 3, 29, 0, 48, 40),
#                'latitude': -34.2648,
#                'longitude': 141.6325,
#                'surface_temperature_celcius': 51}],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('6481357e25c02be8d1a0981a'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 4, 20, 0, 0),
#  'hotspots': [{'confidence': 84,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 44, 20),
#                'latitude': -36.8871,
#                'longitude': 145.1536,
#                'surface_temperature_celcius': 58},
#               {'confidence': 59,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 36),
#                'latitude': -38.4685,
#                'longitude': 146.673,
#                'surface_temperature_celcius': 40},
#               {'confidence': 60,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 34, 10),
#                'latitude': -36.8922,
#                'longitude': 145.1252,
#                'surface_temperature_celcius': 40},
#               {'confidence': 93,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 34, 10),
#                'latitude': -37.769,
#                'longitude': 147.94,
#                'surface_temperature_celcius': 72},
#               {'confidence': 77,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 33, 40),
#                'latitude': -36.0799,
#                'longitude': 146.0784,
#                'surface_temperature_celcius': 50},
#               {'confidence': 88,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 33, 20),
#                'latitude': -36.0829,
#                'longitude': 146.0621,
#                'surface_temperature_celcius': 63},
#               {'confidence': 90,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 50),
#                'latitude': -36.1303,
#                'longitude': 146.3606,
#                'surface_temperature_celcius': 67},
#               {'confidence': 67,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 50),
#                'latitude': -37.7615,
#                'longitude': 147.9169,
#                'surface_temperature_celcius': 45},
#               {'confidence': 63,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#                'latitude': -36.8079,
#                'longitude': 145.1409,
#                'surface_temperature_celcius': 42},
#               {'confidence': 85,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#                'latitude': -37.7783,
#                'longitude': 147.9284,
#                'surface_temperature_celcius': 60},
#               {'confidence': 79,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#                'latitude': -36.8846,
#                'longitude': 145.1679,
#                'surface_temperature_celcius': 52},
#               {'confidence': 80,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#                'latitude': -37.2341,
#                'longitude': 149.1736,
#                'surface_temperature_celcius': 53},
#               {'confidence': 63,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#                'latitude': -36.9189,
#                'longitude': 147.5603,
#                'surface_temperature_celcius': 52},
#               {'confidence': 98,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#                'latitude': -36.1345,
#                'longitude': 146.351,
#                'surface_temperature_celcius': 84},
#               {'confidence': 87,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 4, 32, 30),
#                'latitude': -36.9246,
#                'longitude': 147.5559,
#                'surface_temperature_celcius': 62},
#               {'confidence': 64,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 19),
#                'latitude': -36.085,
#                'longitude': 145.9096,
#                'surface_temperature_celcius': 42},
#               {'confidence': 88,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 18, 40),
#                'latitude': -38.1301,
#                'longitude': 143.9398,
#                'surface_temperature_celcius': 63},
#               {'confidence': 69,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 18, 20),
#                'latitude': -37.7087,
#                'longitude': 145.5499,
#                'surface_temperature_celcius': 45},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 18, 20),
#                'latitude': -36.5865,
#                'longitude': 145.2081,
#                'surface_temperature_celcius': 111},
#               {'confidence': 73,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 17, 10),
#                'latitude': -36.8702,
#                'longitude': 144.0381,
#                'surface_temperature_celcius': 47},
#               {'confidence': 99,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 17, 10),
#                'latitude': -36.1586,
#                'longitude': 145.6666,
#                'surface_temperature_celcius': 85},
#               {'confidence': 74,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 16, 50),
#                'latitude': -37.8672,
#                'longitude': 143.8194,
#                'surface_temperature_celcius': 48},
#               {'confidence': 78,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 15, 30),
#                'latitude': -36.5956,
#                'longitude': 145.206,
#                'surface_temperature_celcius': 51},
#               {'confidence': 77,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 14, 20),
#                'latitude': -37.2197,
#                'longitude': 148.8134,
#                'surface_temperature_celcius': 50},
#               {'confidence': 96,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 14, 10),
#                'latitude': -36.5847,
#                'longitude': 145.1968,
#                'surface_temperature_celcius': 78},
#               {'confidence': 89,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 13, 40),
#                'latitude': -37.6997,
#                'longitude': 145.5519,
#                'surface_temperature_celcius': 64},
#               {'confidence': 61,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 13, 30),
#                'latitude': -37.932,
#                'longitude': 146.1845,
#                'surface_temperature_celcius': 50},
#               {'confidence': 76,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 13, 10),
#                'latitude': -36.6407,
#                'longitude': 144.2957,
#                'surface_temperature_celcius': 50},
#               {'confidence': 63,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 13),
#                'latitude': -36.1569,
#                'longitude': 145.6554,
#                'surface_temperature_celcius': 41},
#               {'confidence': 54,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 13),
#                'latitude': -36.6363,
#                'longitude': 144.3033,
#                'surface_temperature_celcius': 40},
#               {'confidence': 76,
#                'date': datetime.datetime(2022, 4, 20, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 20, 0, 12, 50),
#                'latitude': -37.2212,
#                'longitude': 148.8262,
#                'surface_temperature_celcius': 49}],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('6481357e25c02be8d1a09820'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 4, 26, 0, 0),
#  'hotspots': [{'confidence': 56,
#                'date': datetime.datetime(2022, 4, 26, 0, 0),
#                'datetime': datetime.datetime(2022, 4, 26, 13, 26, 10),
#                'latitude': -36.5511,
#                'longitude': 146.7819,
#                'surface_temperature_celcius': 34}],
#  'max_wind_speed': 20.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('6481357e25c02be8d1a0983f'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2022, 5, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.35,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('6481357e25c02be8d1a09842'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2022, 5, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('6481357e25c02be8d1a09864'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 7, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('6481357e25c02be8d1a0987c'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 7, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('6481357e25c02be8d1a09886'),
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2022, 8, 6, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('6481357e25c02be8d1a0989a'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 8, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  '_id': ObjectId('6481357e25c02be8d1a098a4'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2022, 9, 5, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('6481357e25c02be8d1a098a6'),
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2022, 9, 7, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('6481357e25c02be8d1a098ae'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 9, 15, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('6481357e25c02be8d1a098c2'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2022, 10, 5, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('6481357e25c02be8d1a098da'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 10, 29, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 27.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('6481357e25c02be8d1a098db'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 10, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('6481357e25c02be8d1a098ec'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 11, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('6481357e25c02be8d1a098ed'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 11, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6481357e25c02be8d1a098fa'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'hotspots': [{'confidence': 52,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 23, 25, 57),
#                'latitude': -37.635,
#                'longitude': 149.303,
#                'surface_temperature_celcius': 47},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#                'latitude': -37.591,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 53},
#               {'confidence': 51,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#                'latitude': -37.59,
#                'longitude': 149.31,
#                'surface_temperature_celcius': 42},
#               {'confidence': 64,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 15, 38, 36),
#                'latitude': -37.633,
#                'longitude': 149.264,
#                'surface_temperature_celcius': 42},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#                'latitude': -37.585,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 54},
#               {'confidence': 69,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#                'latitude': -37.58,
#                'longitude': 149.331,
#                'surface_temperature_celcius': 35},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 15, 38, 35),
#                'latitude': -37.583,
#                'longitude': 149.316,
#                'surface_temperature_celcius': 49},
#               {'confidence': 61,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 15, 38, 32),
#                'latitude': -37.38,
#                'longitude': 149.334,
#                'surface_temperature_celcius': 31},
#               {'confidence': 62,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#                'latitude': -37.602,
#                'longitude': 149.295,
#                'surface_temperature_celcius': 33},
#               {'confidence': 64,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#                'latitude': -37.598,
#                'longitude': 149.29,
#                'surface_temperature_celcius': 32},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#                'latitude': -37.596,
#                'longitude': 149.319,
#                'surface_temperature_celcius': 38},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#                'latitude': -37.63,
#                'longitude': 149.232,
#                'surface_temperature_celcius': 42},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#                'latitude': -37.644,
#                'longitude': 149.233,
#                'surface_temperature_celcius': 55},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 12, 22, 15),
#                'latitude': -37.642,
#                'longitude': 149.263,
#                'surface_temperature_celcius': 65},
#               {'confidence': 100,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 12, 22, 14),
#                'latitude': -37.634,
#                'longitude': 149.237,
#                'surface_temperature_celcius': 71},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 4, 35),
#                'latitude': -37.384,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 59},
#               {'confidence': 73,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 4, 35),
#                'latitude': -37.389,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 50},
#               {'confidence': 98,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#                'latitude': -37.605,
#                'longitude': 149.302,
#                'surface_temperature_celcius': 83},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#                'latitude': -37.627,
#                'longitude': 149.261,
#                'surface_temperature_celcius': 57},
#               {'confidence': 84,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#                'latitude': -37.623,
#                'longitude': 149.284,
#                'surface_temperature_celcius': 61},
#               {'confidence': 99,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#                'latitude': -37.6,
#                'longitude': 149.325,
#                'surface_temperature_celcius': 86},
#               {'confidence': 69,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 4, 34, 57),
#                'latitude': -37.61,
#                'longitude': 149.279,
#                'surface_temperature_celcius': 48},
#               {'confidence': 60,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 21),
#                'latitude': -37.637,
#                'longitude': 146.288,
#                'surface_temperature_celcius': 42},
#               {'confidence': 83,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#                'latitude': -37.608,
#                'longitude': 149.282,
#                'surface_temperature_celcius': 58},
#               {'confidence': 87,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#                'latitude': -37.62,
#                'longitude': 149.294,
#                'surface_temperature_celcius': 63},
#               {'confidence': 95,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#                'latitude': -37.618,
#                'longitude': 149.281,
#                'surface_temperature_celcius': 76},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#                'latitude': -37.61,
#                'longitude': 149.296,
#                'surface_temperature_celcius': 56},
#               {'confidence': 73,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#                'latitude': -37.603,
#                'longitude': 149.324,
#                'surface_temperature_celcius': 51},
#               {'confidence': 81,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#                'latitude': -37.602,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 55},
#               {'confidence': 69,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 53),
#                'latitude': -37.6,
#                'longitude': 149.297,
#                'surface_temperature_celcius': 50},
#               {'confidence': 64,
#                'date': datetime.datetime(2022, 11, 30, 0, 0),
#                'datetime': datetime.datetime(2022, 11, 30, 0, 20, 49),
#                'latitude': -37.382,
#                'longitude': 149.341,
#                'surface_temperature_celcius': 41}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# *3. The dataset we have is small for now. However, the number of stations and data points will increase significantly once we deploy our database and application in production. Considering those queries in Task 2 as typical use cases, think about how to optimise your mongodb database. Based on your data model and typical use cases, add simple or compound indexes to your collection. You also need to consider high data ingestion rate and design your indexes accordingly. Please justify your index design.*

# %% [markdown]
# #### `Justification:` ####
#
# The 'date' field in the collection has been added as an index primarily because it serves as an identifier to establish the connection between climate data and hotspot data in the embedded data model where they are linked based on the shared date. Additionally, as the dataset grows and the rate of data ingestion increases, the 'date' index is able to handle the influx of new data well. Its presence enables expedited identification and retrieval of individual or groups of documents based on specific dates, facilitating real-time analysis and processing easily as each document in the collection has a unique date value.
#
# Considering the typical queries used in Task 2, which often involve filtering or retrieving data based on specific dates or date ranges, the 'date' index greatly enhances query performance. By narrowing down the search space, the use of 'date' index minimizes the number of documents that need to be examined, resulting in faster query execution and improved overall efficiency. The following example (Query A in Task 2) is used to showcase the performance improvement achieved by adding the 'date' index to the collection.

# %% [markdown]
# #### Before adding 'date' index: ####
# We can see that the number of documents being examined 'totalDocsExamined' is 366 which is the same as the total number of documents in the collection. This shows the inefficiency in querying the single document with the unique target date of 12-12-2022 as it searches over the entire collection which is time consuming.

# %%
# before creating date as index
collection.find({'date': target_date}, {'_id': 0, 'hotspots': 0}).explain()['executionStats']
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 0,
#  'totalKeysExamined': 0,
#  'totalDocsExamined': 366,
#  'executionStages': {'stage': 'PROJECTION_DEFAULT',
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 0,
#   'works': 368,
#   'advanced': 1,
#   'needTime': 366,
#   'needYield': 0,
#   'saveState': 0,
#   'restoreState': 0,
#   'isEOF': 1,
#   'transformBy': {'_id': 0, 'hotspots': 0},
#   'inputStage': {'stage': 'COLLSCAN',
#    'filter': {'date': {'$eq': datetime.datetime(2022, 12, 12, 0, 0)}},
#    'nReturned': 1,
#    'executionTimeMillisEstimate': 0,
#    'works': 368,
#    'advanced': 1,
#    'needTime': 366,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'direction': 'forward',
#    'docsExamined': 366}},
#  'allPlansExecution': []}

# %% [markdown]
# #### After adding 'date' index: ####
#
# We can see that the number of documents being examined 'totalDocsExamined' has been reduced to 1. This means that the 'date' index helps us to identify and retrieve the document with the specific date straightaway without the need to go over the entire collection, demonstrating the effectiveness of the 'date' index.

# %%
# create date as index
result = collection.create_index([('date', pymongo.ASCENDING)])
sorted(list(collection.index_information()))
# Out:
# ['_id_', 'date_1']

# %%
# after creating date as index
collection.find({'date': target_date}, {'_id': 0, 'hotspots': 0}).explain()['executionStats']
# Out:
# {'executionSuccess': True,
#  'nReturned': 1,
#  'executionTimeMillis': 2,
#  'totalKeysExamined': 1,
#  'totalDocsExamined': 1,
#  'executionStages': {'stage': 'PROJECTION_DEFAULT',
#   'nReturned': 1,
#   'executionTimeMillisEstimate': 3,
#   'works': 2,
#   'advanced': 1,
#   'needTime': 0,
#   'needYield': 0,
#   'saveState': 0,
#   'restoreState': 0,
#   'isEOF': 1,
#   'transformBy': {'_id': 0, 'hotspots': 0},
#   'inputStage': {'stage': 'FETCH',
#    'nReturned': 1,
#    'executionTimeMillisEstimate': 3,
#    'works': 2,
#    'advanced': 1,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'docsExamined': 1,
#    'alreadyHasObj': 0,
#    'inputStage': {'stage': 'IXSCAN',
#     'nReturned': 1,
#     'executionTimeMillisEstimate': 3,
#     'works': 2,
#     'advanced': 1,
#     'needTime': 0,
#     'needYield': 0,
#     'saveState': 0,
#     'restoreState': 0,
#     'isEOF': 1,
#     'keyPattern': {'date': 1},
#     'indexName': 'date_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'date': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'date': ['[new Date(1670803200000), new Date(1670803200000)]']},
#     'keysExamined': 1,
#     'seeks': 1,
#     'dupsTested': 0,
#     'dupsDropped': 0}}},
#  'allPlansExecution': []}
